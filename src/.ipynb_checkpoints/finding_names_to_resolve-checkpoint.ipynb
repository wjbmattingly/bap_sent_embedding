# %%
import json
import glob
from collections import Counter

# %%
files = glob.glob(f"../data/data_saha/*/*/*.json")
print (len(files))
# Out:
# 2370

# %%
speakers = {}
for filename in files:
    with open (filename, "r") as f:
        data = json.load(f)
    tmp = data["header"]["speakers"]
    for t in tmp:
        if t in speakers.keys():
            if filename not in speakers[t]:
                speakers[t].append(filename)
        else:
            speakers[t] = [filename]
# speakers = list(set(speakers))
# speakers.sort()

# %%
len(speakers)
# Out:
# 5757

# %%
with open ("../data/all_speakers.json", "w") as f:
    json.dump(speakers, f, indent=4)

# %%
connected = {}
lastnames = []
false_pos = []
for s in speakers:
    if len(s.split()) > 1 and len(s.split()) < 5:
        item = s
        if " AT " not in item and " BY " not in item and "REPLY" not in item and "ADDRESSES" not in item and "ARGUMENT" not in item and "REEXAMINATION" not in item:
            last = s.split()[-1]
            if len(last) > 2:
                lastnames.append(last)
    if len(s.split()) > 4:
        false_pos.append(s)
potential = Counter(lastnames)
connected = {}
connected_more = {}
for p in potential:
    name = potential[p]
    if name == 2:
        for s in speakers:
            while "  " in s:
                s = s.replace("  ", " ")
            s = s.replace("NO FURTHER QUESTIONS BY ", "").replace("NO FURTHER CROSSEXAMINATION BY ", "").replace("EXAMINAION BY ", "").replace("CROSS EXAMINATION ", "").replace("NO QUESTIONS BY ", "").replace("QUESTIONS BY ", "")
            s = s.replace("NO CROSSEXAMINATION BY ", "").replace("CROSSEXAMINATION BY ", "").replace("FURTHER CROSSEXAMINATION ", "").replace("CROSSEXAMINATION ", "").replace("NO EXAMINATION BY ", "")
            if len(s.split()) > 0:
                if p == s.split()[-1]:
                    # item = s
                    # if " BY " not in item and "REPLY" not in item and "ADDRESSES" not in item and "ARGUMENT" not in item and "REEXAMINATION" not in item
                    if p in connected:
                        if s not in connected[p]:
                            connected[p].append(s)
                    else:
                        connected[p] = [s]
    elif name > 2:
        for s in speakers:
            while "  " in s:
                s = s.replace("  ", " ")
            s = s.replace("NO FURTHER QUESTIONS BY ", "").replace("NO FURTHER CROSSEXAMINATION BY ", "").replace("EXAMINAION BY ", "").replace("CROSS EXAMINATION ", "").replace("NO QUESTIONS BY ", "").replace("QUESTIONS BY ", "")
            s = s.replace("NO CROSSEXAMINATION BY ", "").replace("CROSSEXAMINATION BY ", "").replace("FURTHER CROSSEXAMINATION ", "").replace("CROSSEXAMINATION ", "").replace("NO EXAMINATION BY ", "")
            if len(s.split()) > 0:
                if p == s.split()[-1]:
                
                    if p in connected_more:
                        connected_more[p].append(s)
                    else:
                        connected_more[p] = [s]

# for c in connected:
#     longest = ""
#     for item in connected[c]:
#         if len(item) > len(longest) and " BY " not in item and "REPLY" not in item and "ADDRESSES" not in item and "ARGUMENT" not in item and "REEXAMINATION" not in item:
#             if item.split()[-1] == c:
#                 longest = item
#     connected[c] = longest
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [40], in <cell line: 16>()
#      40 if p == s.split()[-1]:
#      42     if p in connected_more:
# ---> 43         if s not in connected[p]:
#      44             connected[p].append(s)
#      46     else:
#
# KeyError: 'MTHEMBU'

# %%
print (len(connected), len(connected_more))
# Out:
# 279 446

# %%
for c in connected_more:
    print (c)
    print (connected_more[c])
# Out:
# MTHEMBU
# ['MR MTHEMBU', 'ADV MTHEMBU', 'ADV MTHEMBU', 'PETROS VUSUMUZI MTHEMBU', 'MR MTHEMBU', 'DUMISANI MTHEMBU', 'NIMROD MBEWU MTHEMBU', 'ALFRED SIKILELE MTHEMBU', 'VICTOR MTHANDENI MTHEMBU', 'VICTOR MTHEMBU', 'MANDLA MOSES MTHEMBU', 'MRS MTHEMBU', 'OBED MTHEMBU', 'A MTHEMBU', 'LINDIWE MTHEMBU', 'MS MTHEMBU', 'SARAH MTHEMBU', 'MARIA MTHEMBU', 'MS M MTHEMBU', 'ELPHEUS MTHEMBU']
# DOLO
# ['PHILA MARTIN DOLO', 'MR DOLO', 'PILA MARTIN DOLO']
# SANDI
# ['ADV SANDI', 'MR SANDI', 'ADV MR SANDI', 'MRS SANDI', 'MS SANDI', 'MR SANDI', 'MR SANDI', 'N SANDI']
# GQOMFA
# ['LUYANDA GQOMFA', 'HUMPHREY LUYANDA GQOMFA', 'MR GQOMFA']
# SIBANYONI
# ['MR SIBANYONI', 'SIBANYONI', 'MR SIBANYONI', 'ADV SIBANYONI']
# TSEMANE
# ['MR D TSEMANE', 'MR TSEMANE', 'MR L TSEMANE', 'MISS TSEMANE', 'MS H TSEMANE', 'MS A TSEMANE', 'MS TSEMANE']
# MOTATA
# ['ADV MOTATA', 'MR MOTATA', 'JUDGE MOTATA', 'ADVOCATE MOTATA']
# KHAMPEPE
# ['MS KHAMPEPE', 'MISS KHAMPEPE', 'MRS KHAMPEPE', 'JUDGE KHAMPEPE', 'MS SISI KHAMPEPE', 'MS KHAMPEPE', 'ADV KHAMPEPE']
# NDLOVU
# ['ALFAS MABORE NDLOVU', 'MR NDLOVU', 'MRS NDLOVU', 'M R NDLOVU', 'ANNA NOMTANDA NDLOVU', 'THAMSANQA NDLOVU', 'NKANYISO WILFRED NDLOVU', 'BERTWELL BHEKI NDLOVU', 'PHINEAS NDLOVU', 'SIMPHIWE NDLOVU', 'SIMPHIWE GODFREY NDLOVU', 'ANGELINA SIBONGILE NDLOVU', 'JABU NDLOVU', 'JOE NDLOVU', 'MASILITSO M NDLOVU', 'MATHOMBI JANET NDLOVU', 'THANDEKA NDLOVU', 'THOKOZILE ELKE NDLOVU', 'NTOMBIZONKE LINAH NDLOVU', 'ANNA NDLOVU', 'ELLIOT NDLOVU']
# MOKOENA
# ['MOLWEDI MOKOENA', 'LEFU PATRICK MOKOENA', 'MR MOKOENA', 'BUSISISWE MOKOENA', 'JOEL BOYKI MARAPISI MOKOENA', 'JOEL MARAPISI MOKOENA', 'ELSIE MOKOENA', 'CAROLINA SINKEPENG MOKOENA', 'DIPHO MOKOENA']
# VISSER
# ['MR VISSER', 'CROSSMR VISSER', 'MR VISSER', 'MRS VISSER', 'REEXAMINTION BY MR VISSER', 'Mr VISSER', 'EXAMINATION BY ADV VISSER', 'ADV VISSER', 'VISSER', 'SCHALK JAN VISSER', 'MNR VISSER', 'MARIUS ETIENNE VISSER', 'ANDRE FRANCOIS VISSER', 'ADV VISSER', 'FURTHER EXAMINATION BY ADV VISSER', 'ADV VISSER', 'MR VISSER']
# PLESSIS
# ['ADV DU PLESSIS', 'MR DU PLESSIS', 'JOHAN WILHELM DU PLESSIS', 'MR P DU PLESSIS', 'MR H DU PLESSIS', 'MR HERMANUS BAREND DU PLESSIS', 'HERMANUS DU PLESSIS', 'HERMANUS BAREND DU PLESSIS', 'H B DU PLESSIS', 'EXAMINATION BY ADV DU PLESSIS', 'ADV DU PLESSIS', 'REEXAMINATION BY MR DU PLESSIS', 'MR DU PLESSIS', 'NO REEXAMINATION BY MR DU PLESSIS', 'REEXAMINATION BY ADV DU PLESSIS', 'EXAMINATION BY MR DU PLESSIS', 'JEAN DU PLESSIS', 'FURTHER EXAMINATION BY ADV DU PLESSIS', 'ADV DU PLESSIS', 'FURTHER REEXAMINATION BY ADV DU PLESSIS', 'DU PLESSIS', 'RE EXAMINATION BY ADV DU PLESSIS', 'KOBUS DU PLESSIS', 'BOBBY GODSELL NICK SEGAL ADRIAN DU PLESSIS', 'MNR DU PLESSIS', 'PROF DU PLESSIS']
# MPSHE
# ['MR MPSHE', 'ADV MPSHE', 'ADVOCATE MPSHE', 'ADV MPSHE', 'MR MPSHE', 'MR MPSHE', 'ADV MPSHE', 'MR MPSHE', 'MR MPSHE', 'MR MPSHE', 'MR MPSHE', 'BMR MPSHE', 'MNR MPSHE', 'EXAMINATION BY ADV MPSHE', 'MR MPSHE', 'MPSHE', 'MR MPSHE', 'ADV MPSHE', 'NO EXAMINATION BY ADV MPSHE', 'ONDERVRAGING DEUR ADV MPSHE']
# NGOEPE
# ['JUDGE NGOEPE', 'MR NGOEPE', 'ADV ARENDSEJUDGE NGOEPE', 'JUDGE NGOEPE']
# JAGER
# ['ADV DE JAGER', 'JUDGE DE JAGER', 'ADV DE JAGER', 'MR DE JAGER', 'MRADV DE JAGER', 'JAGER', 'ADVDE JAGER', 'ADVOCATE DE JAGER', 'ADV CHRIS DE JAGER', 'ADV DE JAGER', 'COL DE JAGER']
# WILSON
# ['JUDGE WILSON', 'JUDGE WILSON', 'MR WILSON', 'JUDGE WILSON', 'JUDGE WILSON', 'REGTER WILSON', 'TIM WILSON']
# BIZOS
# ['ADV BIZOS', 'MR BIZOS', 'ARGUMENT BY MR BIZOS', 'ADV BIZOS', 'MR BIZOS', 'M R BIZOS', 'BY MR BIZOS', 'FURTHER MR BIZOS']
# PRINSLOO
# ['ADV PRINSLOO', 'MR PRINSLOO', 'MR PRINSLOO', 'NICOLAS MARTHINUS PRINSLOO', 'MR PRINSLOO', 'MNR PRINSLOO', 'MR PRINSLOO', 'ADV PRINSLOO', 'MR PRINSLOO', 'KRUISONDERVRAGING DEUR ADV PRINSLOO', 'NICO PRINSLOO']
# KOCK
# ['MR DE KOCK', 'EUGENE ALEXANDER DE KOCK', 'EUGENE DE KOCK', 'DS DE KOCK', 'HELENE KROON DE KOCK']
# COETZEE
# ['MR COETZEE', 'DIRK COETZEE', 'DIRK JOHANNES COETZEE', 'MR DIRK COETZEE', 'COETZEE', 'LOUIS FERDINAND COETZEE', 'PETRUS JOHANNES COETZEE']
# JOUBERT
# ['MR JOUBERT', 'MISS JOUBERT', 'GEN JOUBERT', 'MAJ GEN JOUBERT', 'MAJOR GENERAL JOUBERT']
# MALAN
# ['MR MALAN', 'ADV MALAN', 'MALAN', 'MR MALAN', 'ADV MALAN', 'DR MALAN']
# SPEAKER
# ['UNKNOWN SPEAKER', 'UNIDENTIFIED SPEAKER', 'MALE SPEAKER', 'MALE SPEAKER ', 'SPEAKER', 'NAFCOC SPEAKER', 'SACCOB SPEAKER', 'SACCOB SPEAKER ', 'UNKOWN SPEAKER', 'ARMSCOR SPEAKER', 'FABCOS SPEAKER', 'FEMALE SPEAKER']
# KHOTLE
# ['LERATO ABEL KHOTLE', 'ABEL OUPA LERATO KHOTLE', 'MOSIUWA ISAIA KHOTLE', 'ABEL OUPA KHOTLE', 'OUPA KHOTLE', 'MOSUIWA ISIAH KHOTLE']
# MORRISON
# ['MOALUSI MORRISON', 'CELESTE MORRISON', 'MALUSI MORRISON', 'BISHOP MARTIN MORRISON']
# MOHAPE
# ['MOHLOLO PAULOS MOHAPE', 'WHITE MOHAPE', 'MR MOHAPE', 'NOHLE MOHAPE']
# CASTRO
# ['PEDRO IGNACIO DE CASTRO', 'MR P DE CASTRO', 'JOAO AVALENO DE CASTRO', 'MR J DE CASTRO']
# GCABASHE
# ['ADV GCABASHE', 'MS GCABASHE', 'MR GCABASHE', 'ADVOCATE GCABASHE', 'MRS GCABASHE', 'MS V GCABASHE']
# MONTSO
# ['ANNIE MONTSO', 'MRS MONTSO', 'MR MONTSO']
# MASILO
# ['TREVOR MASILO', 'MR MASILO', 'MR MASILO']
# SIMELANE
# ['EDWIN TOSIMELA SIMELANE', 'ZAKHELE SIMELANE', 'PATRICK SMANGALISO SIMELANE', 'SMANGALISO PATRICK SIMELANE', 'MRS SIMELANE', 'EUNICE SIMELANE', 'MS SIMELANE', 'MATHEW SIMELANE', 'JOHANNES SIMELANE']
# LEBEA
# ['TITUS LETHOHONOLO LEBEA', 'MR LEBEA', 'ME LEBEA', 'MR K LEBEA', 'KING LEBEA']
# KHUMALO
# ['BONGANI KHUMALO', 'ARCHIE KHUMALO', 'MR KHUMALO', 'BEKHISISO ALEX KHUMALO', 'BHEKISISA ALEX KHUMALO', 'BONGANI CHRISTOPHER KHUMALO', 'JABULANI KHUMALO', 'BONGA KHUMALO', 'BAFANA EDDIE KHUMALO', 'MRS KHUMALO', 'THERESA KHUMALO', 'MFANAFUTHI KHUMALO', 'GLADYS KHUMALO', 'VUSUMUZI KHUMALO', 'CLARA JABHILE KHUMALO', 'MR DUMA JOSHUA KHUMALO']
# JOHNSON
# ['MR JOHNSON', 'NSITSIKELO DON JOHNSON', 'MZIMKHULU JOHNSON', 'NOMAWHETU FRANSISCA JOHNSON', 'LULU JOHNSON']
# MAPOMA
# ['MR MAPOMA', 'MR MAPOMA', 'MR Z MAPOMA', 'ADV MAPOMA']
# THULO
# ['DAELE DANIEL THULO', 'MESHACK TSEKO THULO', 'MARTHA M THULO']
# NGONO
# ['THOBEKA MARTHA NGONO', 'MS NGONO', 'MR NGONO']
# THABETHE
# ['ADV THABETHE', 'MISS THABETHE', 'MS THABETHE', 'MR THABETHE', 'CROSSEXAMINED BY MS THABETHE']
# LEEUW
# ['HENDRIK LEEUW', 'MR LEEUW', 'H LEEUW']
# MAY
# ['MISHEK MAY', 'MR MAY', 'LEBOANE JOHN MAY', 'EMBROSE NZIMKULU MAY', 'MS MAY', 'KUKU GLADYS MAY', 'DANILE WILBERFORCE MAY', 'D MAY']
# MAGODA
# ['DANIEL MAGODA', 'MR MAGODA', 'AKINA MAGODA']
# NGO
# ['MPEZELE NELSON NGO', 'MR NGO', 'M N NGO', 'MN NGO', 'NELSON NGO', 'MPHITHIZELI NELSON NGO']
# OBJECTS
# ['MR NEMANE OBJECTS', 'MR MPSHE OBJECTS', 'MR VISSER OBJECTS', 'MR DU PLESSIS OBJECTS', 'ADV ARENDSE OBJECTS', 'ADVOCATE LOURENS OBJECTS', 'MR TSHOLANKU OBJECTS', 'MR BOOYENS OBJECTS', 'MR PRINSLOO OBJECTS', 'ADV MPSHE OBJECTS']
# MEMANI
# ['ADVOCATE MEMANI', 'ADV MEMANI', 'MR MEMANI', 'MR MEMANI', 'ADV MEMANI', 'CROSSQUESTIONING BY MR MEMANI']
# MERWE
# ['MR VAN DER MERWE', 'GENERAL VAN DER MERWE', 'JOHANNES VELDE VAN DER MERWE', 'JOHANNES VERDE VAN DER MERWE', 'MR V D MERWE', 'MR V S MERWE', 'WILLEM JOHANNES VAN DER MERWE', 'WILLEM JOHANNES VAN DER MERWE', 'W J VAN DER MERWE', 'MR F VAN DER MERWE', 'MR S VAN DER MERWE', 'GENERAL JOHAN VAN DER MERWE', 'D MERWE', 'SUSAN J VAN DER MERWE', 'JOHANNES STONE VAN DER MERWE', 'JOHANNES FELDE VAN DER MERWE']
# MOTSAMAI
# ['MR MOTSAMAI', 'MOHONAETSE STEPHEN MOTSAMAI', 'MOHONAESE STEPHEN MOTSAMAI', 'MOHONAETSE STEPHEN MOTSAMAI', 'MOHAETSE STEPHEN MOTSAMAI']
# ADJOURNS
# ['COMMITTEE ADJOURNS', 'COMMISSION ADJOURNS', 'HEARING ADJOURNS', 'THE COMMISSION ADJOURNS']
# WALT
# ['PIETER VAN DER WALT', 'MS VAN DER WALT', 'MS VAN DER WALT', 'MS VAN DER WALT', 'MRS VAN DER WALT', 'MEV VAN DER WALT', 'MRS VAN DER WALT', 'ADV VAN DER WALT', 'BENNIE VAN DER WALT']
# PLAATJIES
# ['JANE NONSHABA PLAATJIES', 'JULIAN DION PLAATJIES', 'NONZWAKAZI PLAATJIES', 'BUYELWA INNOCENTIA PLAATJIES']
# STANDER
# ['MR STANDER', 'MR STANDER', 'STANDER', 'MR STANDER']
# BRINK
# ['MR BRINK', 'MR BRINK', 'ADV BRINK', 'CROSSEXAMINIATION BY MR BRINK', 'CROSSEXAMINATIONBY MR BRINK', 'NOFURTHER MR BRINK', 'MR BRINK', 'CROSSEXAMAINTION BY MR BRINK', 'BRINK', 'MR BRINK', 'MR BRINK']
# JANUARY
# ['COMMISSION ADJOURNS UNTIL JANUARY ', 'MR JANUARY', 'MRS JANUARY', 'MR JANUARY', 'MICHAEL JANUARY', 'M JANUARY', 'NOMPUMELELO JANUARY']
# MZUZWANA
# ['MR MZUZWANA', 'ZWELABANTU MZUZWANA', 'MR Z MZUZWANA', 'MATTHEWS MZUZWANA']
# BOKABA
# ['CAPT BOKABA', 'HENDRIK BOKABA', 'SOLOMON BOKABA']
# RESUMPTION
# ['ON RESUMPTION', 'COMMISSION ADJOURNS FOR MINUTES ON RESUMPTION', ' AON RESUMPTION', 'A ON RESUMPTION', 'COMMISSION ADJOURNS FOR TEA ON RESUMPTION', 'MEETING ADJOURNS FOR TEA ON RESUMPTION', 'MEETING ADJOURNS ON RESUMPTION']
# OLIPHANT
# ['SHADRACK TEKU OLIPHANT', 'MALEBU OLIPHANT', 'EB OLIPHANT']
# JACOBS
# ['MS JACOBS', 'MR JACOBS', 'FEZILE DONALD MADODA JACOBS', 'DIKKIE MXOLISI JOHANNES JACOBS', 'BERNARD BONAKELE JACOBS', 'JOHANNES JACOBS']
# MOLEFE
# ['SERAME MOLEFE', 'MR MOLEFE', 'SERAME S MOLEFE', 'MODISE MOLEFE', 'ELPHAS MOLEFE', 'MRS MOLEFE', 'MAKEMISO MOLEFE and LYDIA MOLEFE']
# BERG
# ['MR VAN DEN BERG', 'ADV VAN DER BERG', 'MR VAN DER BERG', 'J P VAN DEN BERG']
# ERASMUS
# ['JACOBUS PETRUS PAULUS ERASMUS', 'MR ERASMUS', 'GERRIT NICHOLIS ERASMUS', 'GN ERASMUS', 'MRS ERASMUS', 'GERRIT NICHOLAS ERASMUS', 'ADV ERASMUS']
# BOSMAN
# ['ADV BOSMAN', 'MR BOSMAN', 'MS BOSMAN', 'ADV BOSMAN', 'ADV G BOSMAN', 'NZIMENI PATRICK BOSMAN']
# PATEL
# ['MR PATEL', 'MS PATEL', 'MS PATEL', 'MS R PATEL', 'MS PATEL', 'MR PATEL', 'ADV PATEL', 'MS R PATEL']
# KRIEL
# ['MR KRIEL', 'MR KRIEL', 'ANDRIES STEPHANUS KRIEL', 'ANDRE STEPHANUS KRIEL', 'ANDRIES STEFANUS KRIEL']
# MYBURGH
# ['MR MYBURGH', 'ABRAHAM LIEBRECHT MYBURGH', 'NEIL MYBURGH']
# ROUX
# ['MR ETIENNE J LE ROUX', 'MR LE ROUX', 'ETIENNE J LE ROUX', 'MR ROUX', 'STEPHANUS MARTHINUS ROUX', 'ALETTA MAGRIETA ROUX', 'MS ROUX']
# FOURIE
# ['ABRAHAM CHRISTOFFEL FOURIE', 'GERHARDUS D FOURIE', 'MRS FOURIE', 'MR FOURIE', 'JEANETTE ANNE FOURIE', 'MRS FOURIE', 'JA FOURIE', 'J A FOURIE', 'P T C J FOURIE', 'EMILY FOURIE']
# VLOK
# ['J H VLOK', 'MR VLOK', 'MR VLOK', 'VLOK']
# VENTER
# ['MR J J VENTER', 'MAUREEN VENTER', 'COLONEL VENTER', 'MR VENTER', 'FAAN VENTER', 'PROF VENTER']
# EXCUSED
# ['WITNESS EXCUSED', 'WITNESS IS EXCUSED', 'MR MAGADE EXCUSED', 'WITNESSES EXCUSED']
# NEL
# ['J P NEL', 'MR NEL', 'MR NEL', 'MR NEL', 'FURTHER MR NEL', 'MR VAN DER MERWE ON BEHALF OF MR NEL', 'JAN JOHANNES NEL', 'HENDRIK CHRISTOFFEL NEL', 'JACOB NEL']
# STEYN
# ['PETRUS PAULUS STEYN', 'JOHANNES ALBERTUS STEYN', 'J A STEYN', 'HENRY JACOBUS STEYN']
# NGWENYA
# ['SIFISO FREDA NGWENYA', 'MRS LINDISWA NGWENYA', 'MRS NGWENYA', 'MRS NJOLI MRS NGWENYA', 'MR NGWENYA', 'NTHOMBIKANI NGWENYA', 'DINGI S NGWENYA', 'PHILEMON NGWENYA']
# ZYL
# ['MR VAN ZYL', 'ABRAM VAN ZYL', 'MNR VAN ZYL', 'JOHAN MARTIN VAN ZYL', 'WILLEM JOHANNES VAN ZYL', 'MR J VAN ZYL', 'VAN ZYL', 'J VAN ZYL', 'ADV VAN ZYL', 'MR VAN ZYL']
# GUMBI
# ['NOKWAZI GUMBI', 'MDUDUZI M GUMBI', 'MS GUMBI']
# KEANE
# ['JOAN KEANE', 'MRS KEANE', 'MR KEANE', 'JOHN KEANE']
# SMIT
# ['MR SMIT', 'JOHANNES COENRAAD SMIT', 'JOHANNES SMIT', 'JOHAN SMIT']
# TERREBLANCHE
# ['VIDEO FOOTAGE EUGENE TERREBLANCHE', 'MS VAN DER WALT SUBMITS A VIDEO RECORDING REGARDING A SPEECH BY EUGENE TERREBLANCHE', 'MR TERREBLANCHE', 'MR TERREBLANCHE']
# XABA
# ['BEKI XABA', 'THEMBA RICHARD XABA', 'MR XABA', 'THABISO ESAU XABA', 'BUSISIWE E XABA', 'ANTHONY LODA XABA', 'JOSEPH MANDLA XABA', 'BUSISO XABA', 'VP XABA']
# SITHOLE
# ['JOHN SITHOLE', 'MR SITHOLE', 'JOHN M SITHOLE', 'ANDRIES SIBOKWAKE SITHOLE', 'SIPHO JOEL SITHOLE', 'LUCKY SITHOLE', 'JOHANNES MCOQUES SITHOLE', 'MRS SITHOLE', 'EUNICE SITHOLE', 'NTOMBILISA SITHOLE', 'DINGILE MELITA SITHOLE', 'WINDY THABILE SITHOLE', 'MARTHA SITHOLE', 'LINDIWE SITHOLE', 'JEREMIAH VICTOR SITHOLE', 'ANTOINETTE SITHOLE', 'ANDREAS MPHANI SITHOLE']
# MBATHA
# ['ELIAS MBATHA', 'TEBELLO TRYWELL MBATHA', 'MRS PATRICIA MBATHA', 'MBUSI PASSION MBATHA', 'LAURENS MBATHA', 'THULANI RICHARD MBATHA', 'MR MBATHA', 'PAULOS MVIGELENI MBATHA', 'PAULOS MCIKELENI MBATHA', 'FLORENCE MBATHA', 'ELIZABETH MBATHA', 'FAITH MBATHA', 'PAULINE MATSIE MBATHA', 'MRS MBATHA', 'JOHANNES MBATHA', 'HEADMAN MBATHA']
# DASTILE
# ['SINDISILE WILFORD DASTILE', 'NA DASTILE', 'NOTELE ANGELINA DASTILE']
# MOTLOKWA
# ['MOHALE OSCAR MOTLOKWA', 'MR MOTLOKWA', 'M O MOTLOKWA']
# SONTI
# ['ZOLA NXEBA MICHAEL SONTI', 'MR SONTI', 'ZOLA NXEBE MICHAEL SONTI']
# CHAIRPERSON
# ['CHAIRPERSON', 'MR CHAIRPERSON', 'MR A CHAIRPERSON', 'PEOPLE ALL STAND UP AS REQUESTED BY CHAIRPERSON', 'ACTING CHAIRPERSON', 'UNKNOWN CHAIRPERSON']
# SHONGWE
# ['MR SHONGWE', 'PELELE L SHONGWE', 'MR D F SHONGWE', 'DERICK FRANK SHONGWE', 'MRS SHONGWE', 'MARY NONGAZI SHONGWE']
# MASHININI
# ['NORMAN SOLLY MASHININI', 'LINAH MASHININI', 'MS MASHININI', 'VIRGINIA MASHININI', 'MR MASHININI']
# AUGUST
# ['JOSEPH MOSHE AUGUST', 'MR LUCKY AUGUST', 'SARAH AUGUST']
# MAYA
# ['MR MAYA', 'MS MAYA', 'MISS MAYA', 'MS MAYA', 'MAYA']
# MEMBER
# ['PANEL MEMBER', 'COMMITTEE MEMBER', 'COMMITTEE MEMBER', 'ANOTHER PANEL MEMBER', 'SECOND PANEL MEMBER']
# POTGIETER
# ['ADV POTGIETER', 'JUDGE POTGIETER', 'J M S POTGIETER', 'MR POTGIETER', 'ADV D POTGIETER', 'POTGIETER', 'MR DENZIL POTGIETER']
# MADUNA
# ['MANDLA MADUNA', 'SIPHO JAPTHA MADUNA', 'MRS MADUNA', 'MAMSONDO MADUNA']
# ARENDSE
# ['MR ARENDSE', 'MR ARENDSE', 'ADV ARENDSE', 'ADV ARENDSE', 'ADV ARENDSE', 'ADV ARENDSE', 'ADV ARENDSE', 'FURTHER ADV ARENDSE', 'EXAMINATION BYADV ARENDSE', 'REEXAMINATIONBY ADV ARENDSE', 'EXAMINATION BY ADV ARENDSE', 'EXAMINATIONBY ADV ARENDSE', 'CROSSEXAMINATIONBY ADV ARENDSE']
# TANDA
# ['WALTER FALIBANGO TANDA', 'WALTER FALIBONGA TANDA', 'F W TANDA']
# SHICEKA
# ['ANDILE SHICEKA', 'ANDELE SHICEKA', 'MR SHICEKA']
# MEYER
# ['MR MEYER', 'CHRISTIAN PETER MEYER', 'MICHAEL MEYER', 'ROELF MEYER', 'DANIEL JOHANNES MEYER']
# WILLIAMS
# ['MR WILLIAMS', 'MR P WILLIAMS', 'MR B WILLIAMS', 'MR B WILLIAMS', 'MS WILLIAMS', 'ERIC WILLIAMS', 'NOMATHAMSANQA MELIA WILLIAMS', 'TEDDY EDWARD MWASE WILLIAMS', 'ROCKLYN MARK WILLIAMS', 'WILLIAMS', 'MOEGAMAT QASIM WILLIAMS']
# JACK
# ['ANDILE JACK', 'TWOBOY JACK', 'BENNETTE NDYUNDYU JACK', 'NOMATHEMBA LYDIA JACK', 'MR JACK']
# BOOI
# ['FUMANIKILE BOOI', 'MS BOOI', 'JUDITH JUSTISIA ZUZIWE BOOI', 'QUESTION BY MS BOOI', 'DANIEL MAHESE BOOI', 'KATE BOOI']
# HENDRICKS
# ['SIDNEY HENDRICKS', 'MR HENDRICKS', 'MNR HENDRICKS']
# ECK
# ['MR VAN ECK', 'JOHANNES FREDERIK VAN ECK', 'JOHANNES FREDERICK VAN ECK']
# MBETHE
# ['MS MBETHE', 'BALEKA MBETHE', 'MR MBETHE']
# CORNELIUS
# ['MR CORNELIUS', 'QUSETIONS BY MR CORNELIUS', 'QUENTIN CORNELIUS', 'Q CORNELIUS', 'MR CORNELIUS', 'EXAMINATION BY MR CORNELIUS', 'MR CORNELIUS', 'REEXAMINATION BY MR CORNELIUS', 'MR CORNELIUS']
# MALAZA
# ['ANTOINETTE MALAZA', 'MS MALAZA', 'MR MALAZA', 'MAMOKETE MALAZA']
# ANDERSON
# ['FELICITY ANDERSON', 'MS ANDERSON', 'MR ANDERSON']
# VERSTER
# ['PIETER JOHANN VERSTER', 'MR VERSTER', 'MNR VERSTER']
# KAHANOVITZ
# ['MR KAHANOVITZ', 'MNR KAHANOVITZ', 'STEVE KAHANOVITZ']
# BASSON
# ['WOUTER J BASSON', 'WOUTER BASSON', 'MR BASSON', 'DR BASSON', 'BASSON']
# BOTHA
# ['CARL CASTELING BOTHA', 'HENDRIK JOHANNES PETRUS BOTHA', 'MR BOTHA', 'HJP BOTHA', 'CORNELIUS JOHANNES BOTHA', 'H J P BOTHA', 'MATHYS CORNELIUS BOTHA', 'MATTHYS CORNELIUS BOTHA', 'MS BOTHA', 'DAWID PETRUS BOTHA', 'MR DAWID PETRUS BOTHA', 'P W BOTHA', 'PIK BOTHA', 'MRS PRALENE MORA BOTHA', 'ME BOTHA', 'NTSIKELELO BOTHA', 'SANDILE BOTHA', 'MNR BOTHA', 'DAWN GEORGINA BOTHA', 'BOTHA', 'ZAMIKHAYA WILBERFORCE BOTHA', 'MRS BOTHA', 'Z W BOTHA', 'PASTOR BOTHA', 'LT COLONEL BOTHA']
# MOOSA
# ['MR MOOSA', 'ADV MOOSA', 'ADV MOOSA', 'MOOSA MOOSA', 'FATIMA MOOSA', 'AHMED MOOSA', 'DR AHMED MOOSA', 'DR A MOOSA']
# NYOKA
# ['MR NYOKA', 'MR NYOKA', 'MR NYOKA', 'ADDRESS BY MR NYOKA', 'ADV NYOKA', 'MS NYOKA', 'NELLY NYOKA', 'DUMISANI NYOKA']
# BOOYENS
# ['ADV BOOYENS', 'MR BOOYENS', 'MR BOOYENS', 'ADV C BOOYENS', 'MR C BOOYENS', 'MY BOOYENS', 'M BOOYENS', 'ADV BOOYENS', 'MR BOOYENS', 'REEXAMINATION BY MR BOOYENS', 'EXAMINATION BY ADV BOOYENS', 'MR BOOYENS', 'MR BOOYENS']
# JANSEN
# ['MR JANSEN', 'JANSEN', 'MR JANSEN', 'MR JANSEN', 'ADV JANSEN', 'ADV JANSEN', 'ADV JANSEN', 'ADV JANSEN', 'MR JANSEN', 'DR DULNY KARL ERINBURGH ANDRE JANSEN']
# MARAIS
# ['MR MARAIS', 'EUGENE MARAIS', 'EZEKIEL MATSIDISO MARAIS', 'MRS MARAIS']
# CAPE
# ['WESTERN CAPE', 'W CAPE', 'EASTERN CAPE', 'CAPE']
# MADASI
# ['VUYISILE LEBRAN MADASI', 'VUYASILE BRIAN MADASI', 'BRIAN MADASI', 'MR MADASI', 'VUYISILE MADASI']
# LANGFORD
# ['MRS LANGFORD', 'ANDREA JEANNETTE LANGFORD', 'A J LANGFORD']
# HUGO
# ['MR S HUGO', 'MR HUGO', 'MR HUGO', 'MR HUGO', 'MR HUGO', 'STEFANUS JOHANNES HUGO', 'MS HUGO']
# MILLER
# ['JUDGE MILLER', 'STEPHANIE MILLER', 'MR MILLER']
# MBANE
# ['JIMMY MBANE', 'MR J MBANE', 'FRANK XHOLA MBANE']
# BERLIN
# ['MS P BERLIN', 'MR P BERLIN', 'MS J BERLIN', 'MS S BERLIN']
# MABALA
# ['ZOLA PRINCE MABALA', 'MR MABALA', 'ZOLA PRINCE MABALA']
# BRODE
# ['MR BRODE', 'BENJAMIN BRODE', 'B BRODE']
# PALM
# ['MR PALM', 'ROLAND LEWIS PALM', 'R L PALM']
# CERQUEIRA
# ['FRANCISCO CERQUEIRA', 'MR CERQUEIRA', 'F CERQUEIRA']
# BENZIEN
# ['JEFFERY BENZIEN', 'MR BENZIEN', 'JEFFERY T BENZIEN']
# GRIEBENAUW
# ['JOHANNES LODIWIKUS GRIEBENAUW', 'GENERAL GRIEBENAUW', 'GEN GRIEBENAUW', 'JOHANNES LODEWIKUS GRIEBENAUW']
# KOTZE
# ['SARAH MARIA KOTZE', 'MS KOTZE', 'MRS KOTZE', 'MR KOTZE', 'WILMA KOTZE']
# MALL
# ['JUDGE MALL', 'MR MALL', 'ADV MALL']
# CRONJE
# ['JAN HATTINGH CRONJE', 'BRIG CRONJE', 'BRIGADIER CRONJE', 'BRIGADIER JACK CRONJE']
# HECHTER
# ['JAQUES HECHTER', 'CAPT HECHTER', 'JACQUES HECHTER', 'CAPE HECHTER', 'CAPTAIN HECHTER']
# MENTZ
# ['WILLEM WOUTER MENTZ', 'CAPT MENTZ', 'CAMP MENTZ', 'CAPE MENTZ']
# SWART
# ['MR SWART', 'ANDRe RENIER SWART', 'CHRIS STALTZ CHRISTO SWART']
# NDINISA
# ['CROSBY KOLANI NDINISA', 'MR NDINISA', 'THEMBA NDINISA']
# SMITH
# ['LORENZO VICTOR SMITH', 'MR SMITH', 'DAVID SMITH', 'TIMOTHY SMITH', 'DESMOND SMITH', 'PROF NICO SMITH']
# NZAMA
# ['BHEKI ALFIUS NZAMA', 'SIBONGISENI GOODLORD LINDA NZAMA', 'BAJABULILE NZAMA']
# WILLS
# ['MR WILLS', 'EXAMINATION BY MR WILLS', 'MR WILLS', 'REEXAMINATION BY MR WILLS', 'NO REEXAMINATION BY MR WILLS', 'JOHN WILLS', ' MR WILLS']
# NTULI
# ['MONTEGUESA BEGUISE NTULI', 'MR NTULI', 'NKOSINATHI IMMANUEL NTULI', 'MRS NTULI', 'KHANYISILE ETHEL NTULI and MBUSI NTULI', 'MBUSI NTULI', 'BHEKI NTULI', 'BEAUTY NTULI', 'RICHARD MAGAU NTULI', 'VUSUMUZI NTULI', 'MPHILO JERRY NTULI']
# ZONDI
# ['MR ZONDI', 'THAMI TULANI ZONDI', 'LINDIWE ZONDI', 'WELLINGTON ZONDI', 'EDMUND ZONDI']
# KLERK
# ['MR DE KLERK', 'MS DE KLERK', 'MO FURTHER ME DE KLERK', 'MR DE KLERK', 'MR DE KLERK', 'ADV DE KLERK', 'WILLEM PETRUS DE KLERK']
# MCHUNU
# ['MR MCHUNU', 'MR MCHUNU', 'DUMISANI MCHUNU', 'THEMBA MCHUNU']
# SCHALKWYK
# ['MR VAN SCHALKWYK', 'MR VAN SCHALKWYK', 'SGT VAN SCHALKWYK']
# NGUBANE
# ['MR NGUBANE', 'MR NGUBANE', 'GEBU FANYANA NGUBANE', 'THEMBILIKE NGUBANE']
# WASSERMAN
# ['LAWRIE WASSERMAN', 'LAURIE WASSERMAN', 'LAWRENCE GERALD WASSERMAN', 'LAWRENCE G WASSERMAN']
# DLAMINI
# ['DUMISANI ERNEST DLAMINI', 'THULASIZWE RAPHAEL DLAMINI', 'MOSES MTU DLAMINI', 'ZANZILE TERRENCE DLAMINI', 'MR DLAMINI', 'PERRY NHLANHLA DLAMINI', 'SOLOMON DLAMINI', 'JUDITH DLAMINI', 'MRS DLAMINI', 'RECORIA JUDITH DLAMINI', 'DAVID ZHELI DLAMINI', 'RICHARD MPAGAMESENE DLAMINI', 'SYLVIA NOMHLE DLAMINI', 'MS DLAMINI', 'BONGINKOSI DLAMINI', 'TOKOZILE DLAMINI', 'DUMUSANI HENRY DLAMINI', 'DAVID PHILIP ZWELI DLAMINI', 'BISHOP DLAMINI']
# HLONGWANE
# ['MR HLONGWANE', 'ALEX BEKHANI HLONGWANE', 'I N HLONGWANE', 'I H HLONGWANE', 'ISRAEL NYONI HLONGWANE', 'ISRAEL HLONGWANE', 'PATRICK HLONGWANE', 'PAUL HLONGWANE', 'SARAPHINA NTOMBIFIKILE HLONGWANE', 'FANA HLONGWANE']
# CELE
# ['TULANI FILEMON MOSES CELE', 'MUSAWENKOSI CELE', 'JABULANI DODA CELE', 'THULANI PERCIVAL CELE', 'ROY BONGUMUSA CELE', 'MR CELE', 'EMILY ZODWA CELE', 'MS E Z CELE', 'SKHOSAZANA HAPPY CELE', 'MS S H CELE', 'JOSHUA CELE', 'MANDLA CELE', 'ROSEMARY CELE', 'ADOLPHUS CELE', 'THEMBINKOSI DWAYISA and KAYIYA BOY CELE']
# RADEBE
# ['JEFFREY THAMSANQA RADEBE', 'MAGOPA SIMON RADEBE', 'SIMON MOGOPO RADEBE', 'MR RADEBE', 'JOHN RADEBE', 'PATRICK MOZAMASHLUBE RADEBE', 'DANNY RADEBE', 'BONGANI VICTOR RADEBE', 'MRS RADEBE', 'M EVELYN RADEBE', 'LANDELWA IVY RADEBE', 'MOSELE ANDRONICA RADEBE', 'RUTH RADEBE', 'ETHEL RADEBE']
# MAHARAJ
# ['MR MAHARAJ', 'SEPTEMBER indistinct MAHARAJ', 'ME MAHARAJ', 'SEPTEMBER MAHARAJ', 'MAC MAHARAJ', 'BREMINAND MAHARAJ']
# ZULU
# ['ZAKHELE AMOS ZULU', 'AARON ZIBUSE ZULU', 'BONGNKOSI ELVIS ZULU', 'TABANI RICHARD ZULU', 'NONHLANHLA TANDAZILE ZULU', 'MR ZULU', 'MRS ZULU', 'KHANYISILE ZULU', 'MS ZULU', 'THOKO ZULU', 'LINDIWE FRANCISCA ZULU', 'E ZULU', 'MOSES ZULU']
# LUTHULI
# ['LINDA HEMAN LUTHULI', 'DALAQOLO WORDSWORTH LUTHULI', 'ALZINA MKAZA LUTHULI', 'DALUTXOLO WORDSWORTH LUTHULI', 'MRS LUTHULI', 'DORCAS LUTHULI', 'DALUXOLO WORDSWORTH LUTHULI']
# ZUMA
# ['BUSIZIWE ANTOINETTE ZUMA', 'BETHUEL MONDLI ZUMA', 'ROBERT V O ZUMA', 'NOMUSA CONSTANCE ZUMA', 'ZUMA']
# GUMEDE
# ['DUMSANE HAMILTON GUMEDE', 'MRS ELIZABETH GUMEDE', 'MRS H E GUMEDE']
# NGCOBO
# ['THEMBA MSHINI NGCOBO', 'GOODMAN MUSAWAKHE NGCOBO', 'MR NGCOBO', 'GOODMAN NGCOBO', 'JUDGE NGCOBO', 'CHRISTOPHER NGCOBO', 'VUYISILE NGCOBO', 'ADELAIDE NGCOBO', 'CLIFFORD MENDISI SIYOLO and EPHRAIM NGCOBO', 'SYLVASIA NGCOBO', 'ALVINA NGCOBO', 'SBONGILE NGCOBO', 'MRS NGCOBO', 'BATHINI NGCOBO', 'NOMUSA SIBONGILE NGCOBO', 'HILDA NTOMBIZODWA NGCOBO', 'MS NGCOBO']
# MNGOMEZULU
# ['HAPPY AUBREY MNGOMEZULU', 'HAPPY MNGOMEZULU', 'DOMINIKA MNGOMEZULU']
# MKHIZE
# ['BERNARD MKHIZE', 'MANDLEKAHISE JOSESPH MKHIZE', 'SHEILA MKHIZE', 'MR MKHIZE', 'ZAMASWAZI TANDI MKHIZE', 'WELCOME MKHIZE', 'BRIAN QUNA MKHIZE', 'BHEKINKOSI MKHAKLAZENI MKHIZE', 'BHEKINKOSI MKHIZE', 'MS MKHIZE', 'ZAMISWAZI MKHIZE', 'FLORENCE MKHIZE', 'MS H MKHIZE', 'MRS MKHIZE', 'SIBONGILE CLARABEL MKHIZE', 'MISS MKHIZE', 'BRIAN GCINA MKHIZE']
# LAMEY
# ['MR LAMEY', 'MR LAMEY', 'MR LAMEY', 'MR LAMEY', 'FURTHER MR LAMEY', 'ADV LAMEY']
# PIENAAR
# ['FREDERIK JOHANNES PIENAAR', 'MRS PIENAAR', 'CORNELIA GETRUDE PIENAAR', 'MR PIENAAR']
# RAS
# ['MARTHINUS DAVID RAS', 'MARTINHUS DAVID RAS', 'MARTINUS RAS', 'MARTINUS CHRISTOFFEL RAS']
# DYK
# ['PAUL JACOBUS VAN DYK', 'JOHANNES HENDRIK VAN DYK', 'MS VAN DYK']
# VERMEULEN
# ['NICHOLAS JOHANNES VERMEULEN', 'NICHOLAS JOHANNES MR VERMEULEN', 'NICOLAAS VERMEULEN', 'NICHOLAAS VERMEULEN', 'NICOLAAS JOHANNES VERMEULEN', 'MR VERMEULEN', 'N J VERMEULEN', 'TREVOR GRIFFITHS VERMEULEN']
# MKHWANAZI
# ['MS MKHWANAZI', 'J A MKHWANAZI', 'FANIE ABRAHAM MKHWANAZI', 'KATELENI MKHWANAZI', 'J MKHWANAZI', 'MR MKHWANAZI', 'BRIG MKHWANAZI']
# NGOBESE
# ['SEBELO NGOBESE', 'MSHANGA NGOBESE', 'MR NGOBESE', 'SIBUSISO AMOS NGOBESE', 'AMOS NGOBESE', 'MRS NGOBESE']
# POSWA
# ['MS POSWA', 'VINCENT POSWA', 'MANDLENKOSI T POSWA']
# WESTHUIZEN
# ['CASPER ADRIAAN VAN DER WESTHUIZEN', 'C A VAN DER WESTHUIZEN', 'MR VAN DER WESTHUIZEN', 'CA VAN DER WESTHUIZEN', 'CHRISTOFFEL PIERRE VAN DER WESTHUIZEN', 'GEN VAN DER WESTHUIZEN', 'MS VAN DER WESTHUIZEN', 'MS VAN DER WESTHUIZEN']
# BAKER
# ['ADRIAN DAVID BAKER', 'MR BAKER', 'C BAKER']
# SHEZI
# ['MR SHEZI', 'AMBROSE SHEZI', 'GLADYS SHEZI']
# NOFOMELA
# ['BUTANA ALMOND NOFOMELA', 'ALMOND BUTANA NOFOMELA', 'MR NOFOMELA', 'MR A NOFOMELA', 'A NOFOMELA', 'ALMOND NOFOMELA']
# MADLALA
# ['THULANI CHRISTOF MADLALA', 'TOM MADLALA', 'MR MADLALA', 'TOM JABULANI MADLALA', 'KHUMBUZILE MILDRED MADLALA', 'NHLANHLA PHILEMON MADLALA']
# ISMAIL
# ['ABOOBAKER ISMAIL', 'MOHAMMED SADIK ISMAIL', 'GEN ISMAIL']
# MNISI
# ['JOHANNES MNISI', 'MANDLINKOSI ENOCH GITAM MNISI', 'MR MNISI', 'JAMEYA GERTRUDE MNISI']
# McBRIDE
# ['ROBERT JOHN McBRIDE', 'MR McBRIDE', 'ROBERT McBRIDE']
# BURTON
# ['MS BURTON', 'MRS BURTON', 'MARY BURTON', 'MR BURTON']
# STATEMENT
# ['MS BURTON READS STATEMENT', 'MR ISMAIL READS STATEMENT', 'MR McBRIDE READS STATEMENT', 'MR MTIMKULU READS STATEMENT', 'MOGGEE READS OUT HIS STATEMENT', 'MR STERRENBERG READS OUT HIS STATEMENT', 'OPENING STATEMENT', 'CLOSING STATEMENT']
# MADONDO
# ['THOKOZILE MAVIS MADONDO', 'MS MADONDO', 'MRS MADONDO', 'MR MADONDO', 'SIPHIWE MADONDO']
# KHUZWAYO
# ['KETHA MPILO KHUZWAYO', 'MR KHUZWAYO', 'M KHUZWAYO', 'MRS KHUZWAYO', 'PHILISUYA KHUZWAYO', 'HOPEWELL KHUZWAYO']
# NTJALI
# ['ANDRIES BONGNKOSI NTJALI', 'MR NTJALI', 'M NTJALI']
# MASEKO
# ['ALBERT SBANGELISO MASEKO', 'MR MASEKO', 'PATRICK THAPELA MASEKO', 'PATRICK THOPELA MASEKO', 'TAPELO MASEKO', 'THAPELO PATRICK MASEKO', 'NELSON ZUZILE MASEKO', 'THOBEKA DORIS MASEKO', 'MS MASEKO', 'JABU MASEKO', 'MARY NOMSA MASEKO', 'MSONGELWA AMOS MASEKO', 'NELSON MASEKO', 'MATHEWS MASEKO', 'ELIZABETH MASEKO']
# TSHABALALA
# ['SIBUSISO ERIC TSHABALALA', 'MR TSHABALALA', 'MANDLA RICHARD TSHABALALA', 'SIPHO ALFRED TSHABALALA', 'S G TSHABALALA', 'ENOCK TSHABALALA', 'ELDA TSHABALALA', 'MS TSHABALALA', 'MR JUSTICE VUKA MSWAZI TSHABALALA', 'DOROTHY TSHABALALA']
# FERRERO
# ['JULIA ARENSI FERRERO', 'MS FERRERO', 'JULIA FERRERO']
# MDLULI
# ['JONES JUDA MDLULI', 'KHANYISILE MDLULI', 'MS MDLULI', 'NTOMBIKHAYISE MDLULI']
# MABASO
# ['FIKILE MABASO', 'SIPHO JEREMIAH MABASO', 'JOSEPH MABASO', 'VICTOR WANDA MUCHACHO MABASO', 'LINDIWE SARAH MABASO', 'MRS MABASO', 'KHANYISILE MABASO']
# NAIDOO
# ['SEGARAN RAMALU NAIDOO', 'S R NAIDOO', 'DEREK NAIDOO', 'DHANPAL NAIDOO', 'MR NAIDOO']
# OFF
# ['MIKE TURNED OFF', 'MACHINE SWITCHED OFF', 'VIDEO IS SWITCHED OFF', 'SWITCHED OFF', 'RECORDING SWITCHED OFF']
# MPANZA
# ['MR MPANZA', 'ZIBA GERALD MPANZA', 'MR M P MPANZA', 'M P MPANZA', 'P M MPANZA']
# SHANDU
# ['MZWAKE SHANDU', 'MRS SHANDU', 'NOMUSA SHANDU', 'BABEKHILE SHANDU', 'ELIAS ZWELAKHE SHANDU']
# SHABALALA
# ['TULANI SHABALALA', 'MBUSO ENOCK SHABALALA', 'MUSONGELWA ALPHEUS SHABALALA', 'MAYROSE SINDISIWE SHABALALA', 'NOMSA SHABALALA', 'MS SHABALALA', 'MRS SHABALALA', 'MS N SHABALALA']
# MOLOI
# ['MR MOLOI', 'SOLOMON MOLOI', 'VICTOR PETER MOLOI', 'STEPHAN CYBUTAN FOSTER MOLOI', 'LEHA MOHLAGATIBI MOLOI', 'MRS MOLOI', 'ROSSY MOLOI']
# MBAMBO
# ['ROMEO MBUSO MBAMBO', 'MR MBAMBO', 'ZUKILE AUGUSTINE MBAMBO', 'ZUKILE MBAMBO', 'GERTRUDE MBAMBO', 'B V MBAMBO', 'ROMEO MBUZO MBAMBO']
# HLOPE
# ['MSIZI JETHRO HLOPE', 'MR HLOPE', 'JABULANI BOBBY HLOPE', 'MAQNOBA ABRAHAM HLOPE']
# KUZWAYO
# ['PILESILE KUZWAYO', 'MRS KUZWAYO', 'SEBUSISO KUZWAYO', 'MR KUZWAYO', 'ELLEN KUZWAYO']
# DLADLA
# ['MABHUNGU ABSALOM DLADLA', 'MR DLADLA', 'LAWRENCE FANIZINI DLADLA', 'MANA BUSISIWE DLADLA', 'MSOLWA SOLOMON DLADLA']
# BUTHELEZI
# ['THEMBA BUTHELEZI', 'SHAKESPEARE BUTHELEZI', 'SHAKESPEARE THAMI BUTHELEZI', 'LUCKY THEMBA BUTHELEZI', 'MR BUTHELEZI', 'MQAMBELENI BUTHELEZI', 'SIPHO ALFRED MR BUTHELEZI', 'NHLANHLA JOHN BUTHELEZI', 'LENA BUTHELEZI', 'MANDLA DOUGLAS BUTHELEZI', 'BONGANI BUTHELEZI', 'MS BUTHELEZI', 'JABULANI BUTHELEZI']
# DUMA
# ['TAMSANQA DUMA', 'MXOLISI DUMA', 'NELSON SAKUMZI DUMA']
# SNYMAN
# ['MR SNYMAN', 'CAPTAIN SNYMAN', 'HAROLD SNYMAN', 'ADV SNYMAN']
# NOKAWUSANA
# ['NZUNZIMA JIMMY NOKAWUSANA', 'JIMMY NOKAWUSANA', 'MELVILLE NOKAWUSANA']
# MATSHAYA
# ['MFANELO DAN MATSHAYA', 'MFANELO MATSHAYA', 'MAGDELINA NOMBULELO MATSHAYA']
# GOLA
# ['ANDILE GOLA', 'THOBANI GOLA', 'MR SITILE SIMON GOLA']
# BAM
# ['MZIMPHLE ELVIS BAM', 'MR MBONGENI NICHOLAS BAM', 'MS B BAM']
# XUNDU
# ['THEMBELANI TANDEKILE XUNDU', 'MR XUNDU', 'REV XUNDU', 'REVEREND XUNDU', 'REVD XUNDU', 'XUNDU', 'N XUNDU', 'M XUNDU']
# STANFORD
# ['ROBERT STANFORD', 'ROBERT NORMAN STANFORD', 'MR STANFORD', 'MR STANFORD STANFORD']
# ZEELIE
# ['MR ZEELIE', 'CHARLES ALFRED ZEELIE', 'MNR ZEELIE']
# SAVAGE
# ['ELIZABETH ANNE SAVAGE', 'BETH SAVAGE', 'MR SAVAGE']
# THUTHA
# ['ZAMA THUTHA', 'MR THUTHA', 'ZUMA THUTHA']
# NKOSI
# ['MR NKOSI', 'SIDNEY VINCENT NKOSI', 'BONGANI NKOSI', 'DUMA MOSES NKOSI', 'WINIFRED NKOSI', 'BUSISIWE NKOSI', 'FLORENCE NKOSI', 'MRS NKOSI', 'DR NKOSI']
# ZWANE
# ['MR ZWANE', 'NICOLAS ZWANE', 'NICHOLAS ZWANE', 'ELIAS ZWANE', 'PULENG ZWANE', 'MISS ZWANE', 'SIPHO ZWANE']
# LUKHELE
# ['LIVINGSTONE M LUKHELE', 'PHILIP JABULANI LUKHELE', 'MR LUKHELE']
# MAJOLA
# ['DAVID ELVIS MAJOLA', 'MBONGENI CLARENCE MAJOLA', 'NOMBUSO MAJOLA', 'BONGENI ALSON MAJOLA', 'MRS MAJOLA', 'NOMTHANDAZO EMILY MAJOLA and BONGINKOSI MAJOLA']
# MSIBI
# ['ALPHEUS DUMUSANE MSIBI', 'JOHANNA MSIBI', 'MR MSIBI']
# SIBIYA
# ['MRS SIBIYA', 'SONNYBOY JOHANNES SIBIYA', 'PINKIE SIBIYA', 'M SIBIYA', 'SIGQANYA SIBUSISO SIBIYA']
# MALINGA
# ['NTOMBI MALINGA', 'JABU JAMES MALINGA', 'MR MALINGA', 'THERESA MALINGA']
# MORRIS
# ['MR SIMON MORRIS', 'MR MORRIS', 'SIMON MORRIS']
# SHOKE
# ['AGGIE SHOKE', 'SOLLIE ZACHERIAS SHOKE', 'MR SHOKE', 'SOLLY ZACHARIA SHOKE']
# PRETORIUS
# ['MR PRETORIUS', 'DR PRETORIUS', 'MR PRETORIUS', 'CROSSMR PRETORIUS', 'LOURENS MARTIN PRETORIUS', 'MS PRETORIUS', 'OL ER PRETORIUS', 'DR OLIVER PRETORIUS']
# TIPP
# ['MR TIPP', 'MR TIPP', 'TIPP', 'DAVIS v TIPP']
# WYK
# ['MR VAN WYK', 'MR P A VAN WYK', 'MR A P VAN WYK', 'MR VAN WYK', 'MR WYK', 'CORNELIUS JOHANNES VAN WYK', 'GERRY VAN WYK', 'MR G VAN WYK', 'AP VAN WYK', 'ANDREW PETER VAN WYK', 'HEILA VAN WYK', 'AP AN WYK', 'H VAN WYK']
# MHLABA
# ['BAFANA GONZWEIZE MHLABA', 'MR MHLABA', 'BAFANA GONZWEIZA MHLABA']
# KHUNGWANE
# ['MR KHUNGWANE', 'JOHANNA KHUNGWANE', 'MS KHUNGWANE', 'LEONARD KHUNGWANE']
# SIMPSON
# ['GRAHAM SIMPSON', 'JAMES SIMPSON', 'MICHAEL ANDREW SIMPSON']
# NKABINDE
# ['NKOSINATHI NKABINDE', 'JAN Z NKABINDE', 'MR NKABINDE', 'MRS HLUPHEKILE NKABINDE']
# MOFOKENG
# ['MICHAEL KGIBA MOFOKENG', 'FUSI SIMON MOFOKENG', 'JACK MOFOKENG', 'MR MOFOKENG', 'LEFOKA LAWRENCE MOFOKENG', 'MR LEFOKA LAWRENCE MOFOKENG', 'ALINA MALEF MOFOKENG', 'BRIG D MOFOKENG']
# SWANEPOEL
# ['MR SWANEPOEL', 'MR SWANEPOEL', 'JOHANN MATHYS ADAM SWANEPOEL', 'WYNAND PIETER SWANEPOEL', 'WYNAND SWANEPOEL', 'REV FREEK SWANEPOEL']
# NHLAPO
# ['KIFUWE MICHAEL NHLAPO', 'MR NHLAPO', 'THEMBA T NHLAPO', 'THEMBA NHLAPO', 'MRS NHLAPO']
# MAKHONDO
# ['MR MAKHONDO', 'JIMMY NKOSINATI MAKHONDO', 'JIMMY NKOSINATHI MAKHONDO']
# NHLAYISI
# ['MS NHLAYISI', 'MS NHLAYISI', 'MRS NHLAYISI']
# TSHABANGU
# ['MBONGENI OTTO TSHABANGU', 'MR TSHABANGU', 'MPLUPEKI SAMU TSHABANGU', 'MPLUPEKI SIMON TSHABANGU', 'MPLUPEKI TSHABANGU']
# MKHONTO
# ['SIPHO ALBERT MKHONTO', 'SGTMAJ MKHONTO', 'SANDISWA MKHONTO']
# SKHOSANA
# ['BRUNO SKHOSANA', 'MR SKHOSANA', 'ELLIOTT SKHOSANA', 'BETTY SKHOSANA', 'JOHANNAH VILIE SKHOSANA']
# NKUNA
# ['MBASIMA RICHARD NKUNA', 'CONRAD NKUNA', 'ALBERT NKUNA']
# MHLONGO
# ['WALTER MUSMUSI MHLONGO', 'MILTON BEKI MHLONGO', 'ZWELI ABSOLON MHLONGO', 'SIZA CYRIL MHLONGO', 'MAHLASELA PAUL MHLONGO', 'MAMSESE MHLONGO']
# DUBE
# ['JOHN ITHUMALENG DUBE', 'MR DUBE', 'JOHN IDMEL DUBE', 'NXUMALE DUBE', 'MRS DUBE', 'GEORGE DUBE', 'NOMALISO DUBE', 'DUMISANI DUBE', 'JOHANNES DUBE']
# MAKHUBU
# ['CLIVE MHLAULI MAKHUBU', 'CLIVE MAHLAULI MAKHUBU', 'NOMBULELO ELIZABETH MAKHUBU']
# MANQELE
# ['MR MANQELE', 'S F MANQELE', 'S F MANQELE']
# RESUMES
# [' BCOMMITTEE RESUMES', 'A COMMISSION RESUMES', 'COMMISSION RESUMES', 'ADJOURNS RESUMES']
# MEIRING
# ['CAREL HENDRICKS MEIRING', 'MR MEIRING', 'CAREL HENDRIK MEIRING', 'PROF MEIRING', 'MR PIET MEIRING', 'PROFESSOR MEIRING', 'PROFF MEIRING', 'JOHAN LODEWYK MEIRING', 'P MEIRING']
# HARTEL
# ['DE HARTEL', 'MS HARTEL', 'MR HARTEL']
# COMMITTEE
# ['ADV BIZOS ADDRESSES THE COMMITTEE', 'MR CLAASSEN ADDRESSES COMMITTEE', 'COMMITTEE', 'MR MBANDAZAYO ADDRESSES COMMITTEE', 'MR NTANUNU ADDRESSES COMMITTEE', 'MS WILD ADDRESSES COMMITTEE', 'MS PATEL ADDRESSES COMMITTEE', 'MR VAN DEN BERG ADDRESSES COMMITTEE', 'ADV PRIOR ADDRESSES COMMITTEE', 'MR SAMUELS ADDRESSES COMMITTEE', 'MR SHEIN ADDRESSES COMMITTEE', 'MR SWANEPOEL ADDRESSES COMMITTEE', 'ADV STEENKAMP ADDRESSES THE COMMITTEE', 'MR MOTEPE ADDRESSES COMMITTEE', 'MS MOLOISANE ADDRESSES COMMITTEE', 'MS THABETHE ADDRESSES COMMITTEE', 'MS MOLOISANE ADDRESSES THE COMMITTEE', 'MS THABETHE ADDRESSES THE COMMITTEE', 'MEMBER OF COMMITTEE', 'MR RUDOLPH ADDRESSES COMMITTEE', 'MR TERREBLANCHE ADDRESSES COMMITTEE', 'MS THABETE ADDRESSES COMMITTEE', 'ADV STEENKAMP ADDRESSES COMMITTEE', 'MEMBER OF THE COMMITTEE', 'MR MHLABA ADDRESSES COMMITTEE', 'MR TAKA ADDRESSES COMMITTEE', 'MAHUDU MATHEE COMMITTEE']
# VUUREN
# ['PAUL JACOBUS JANSEN VAN VUUREN', 'JAKOBUS JAKOB VAN VUUREN', 'MR VAN VUUREN', 'J J VAN VUUREN', 'O VAN VUUREN', 'PAUL VAN VUUREN', 'VAN VUUREN']
# MAAKE
# ['ELIZABETH MAAKE', 'MARTHA MAAKE', 'SHOKI MAAKE', 'MS MAAKE']
# VILAKAZI
# ['SHAYESAKHE BETHWELL VILAKAZI', 'ALINA VILAKAZI', 'PHUMZILE VILAKAZI', 'MRS LINA L VILAKAZI']
# NTOMBELA
# ['VELI RAPHAEL NTOMBELA', 'MTHOKOZISENI NTOMBELA', 'PETRUS NTOMBELA', 'THOKO NORA DLUNGWANE and ZODWA NTOMBELA', 'MRS NTOMBELA']
# MASUPA
# ['GODFREY MASUPA', 'MR MASUPA', 'MRS MASUPA', 'ELINALE MASUPA', 'HENDRIK MASUPA']
# ISAACS
# ['MR ISAACS', 'HENRY ISAACS', 'ELIZABETH FLORA ISAACS']
# SMILES
# ['WALTER SMILES', 'MR SMILES', 'MNR SMILES']
# PETROS
# ['ROLAND PETROS', 'MR PETROS', 'R PETROS']
# COMMISSION
# ['MRS VAN DER WALT ADDRESSES THE COMMISSION', 'MR BLACK ADDRESSES THE COMMISSION', 'MEMBER OF COMMISSION', 'TRUTH AND RECONCILIATION COMMISSION', 'UNIDENTIFIED COMMISSION', 'UNKNOWN COMMISSION']
# MOLOPE
# ['MR MOLOPE', 'MRS MOLOPE', 'SINHA GADIFELE MOLOPE']
# MASANGO
# ['F TING TING MASANGO', 'MR MASANGO', 'F T T MASANGO']
# PONI
# ['XOLISWA CLIFFORD PONI', 'MR PONI', 'NR PONI']
# MTSWENI
# ['JULY MABHOKO MTSWENI', 'PHILLIP MFULATWELWA MTSWENI', 'SPEELMAN ERNEST MTSWENI', 'MRS MTSWENI', 'JENETHA MTSWENI', 'TEMBI MTSWENI', 'MISS MTSWENI', 'MS MTSWENI']
# MAHLANGU
# ['JOHANNES JABULANI MAHLANGU', 'THULANI MAHLANGU', 'MARTHA YEBONA MAHLANGU', 'MS MAHLANGU', 'PRINCE JAMES MAHLANGU', 'ELEANOR MAHLANGU', 'MRS MAHLANGU', 'SOLOMON MAHLANGU', 'MR MAHLANGU', 'GEORGE BERNARD MAHLANGU']
# SKOSANA
# ['CHARLES MICHAEL SKOSANA', 'DERICK SKOSANA', 'MRS B SKOSANA', 'MRS SKOSANA', 'BETTY SKOSANA', 'MS S SKOSANA']
# MOGALE
# ['MR MOGALE', 'EPHRAIM MOGALE', 'PAULINA MOGALE']
# HADEBE
# ['MZOBONA LEONARD HADEBE', 'JOHANNES HADEBE', 'NOTILE HADEBE']
# OOSTHUIZEN
# ['MR OOSTHUIZEN', 'ANDRIES CORNELIUS OOSTHUIZEN', 'ALFRED OOSTHUIZEN']
# KRUGER
# ['MR KRUGER', 'JOHACHIM HEINRICH KRUGER', 'JH KRUGER', 'MS H KRUGER', 'MS KRUGER', 'MRS KRUGER', 'JAN PETRUS KRUGER']
# MAKHAWULA
# ['XHOLILE MAKHAWULA', 'MONWABISI MAKHAWULA', 'MR MAKHAWULA', 'MRS MAKHAWULA']
# MOKGATLE
# ['KINANCHIMA CHRISTOFFEL MOKGATLE', 'MR MOKGATLE', 'MR K C MOKGATLE', 'AARON MOKGATLE', 'MR AARON MOKGATLE', 'CHARLES MOKGATLE', 'MR CHARLES MOKGATLE']
# MTULE
# ['VUSIMUSI ISRAEL MTULE', 'VUSIMUSI ISRAEL MTULE', 'MR V I MTULE', 'MR MTULE']
# NZIMANDE
# ['M A NZIMANDE', 'THEMBANI CATHERINE NZIMANDE', 'MAKOZONKHE ELGIAS NZIMANDE']
# KHANYILE
# ['MR HENRY M KHANYILE', 'VINCENT KUSAHUSA KHANYILE', 'VINCENT KHANYILE']
# SEHLWANA
# ['M M SEHLWANA', 'MR M SEHLWANA', 'MR SEHLWANA']
# STRYDOM
# ['JOHANNES ANDRIES NEL STRYDOM', 'MR STRYDOM', 'MR STRYDOM', 'ADV STRYDOM', 'DE WET JOHAN STRYDOM']
# NIEUWOUDT
# ['GIDEON JOHANNES NIEUWOUDT', 'MR NIEUWOUDT', 'GIDEON JOHANNES NIEUWOUDT', 'GJ NIEUWOUDT']
# RENSBURG
# ['NICHOLAS JACOBUS JANSE VAN RENSBURG', 'MR VAN RENSBURG', 'NICHOLAS JANSE VAN RENSBURG', 'MR JANSEN VAN RENSBURG', 'MR JANSE VAN RENSBURG', 'SCHALK JANSE VAN RENSBURG', 'DR VAN RENSBURG', 'SCHALK VAN RENSBURG', 'BRIGADIER J L J VAN RENSBURG']
# KOK
# ['JACOBUS KOK', 'MR KOK', 'J KOK', 'WILLEM KOK']
# DHLAMINI
# ['ELLEN DHLAMINI', 'LIZAH DHLAMINI', 'MR DHLAMINI']
# STRAATEN
# ['ADRIAAN VAN STRAATEN', 'MR VAN STRAATEN', 'WILLEM VAN STRAATEN', 'GIDEON VAN STRAATEN']
# DERBYLEWIS
# ['MRS GAY DERBYLEWIS', 'MR DERBYLEWIS', 'CLIVE DERBYLEWIS']
# GERBER
# ['HENDRIK GERBER', 'MR GERBER', 'MNR GERBER']
# BRUIN
# ['JOHANNES JAKOBUS DE BRUIN', 'IVOLYN DE BRUIN', 'MS DE BRUIN', 'MR DE BRUIN', 'MRS DE BRUIN', 'ME DE BRUIN']
# VIDEO
# ['ADV DU PLESSIS PLAYS THE VIDEO', 'EXCERPTS OF VIDEO', 'ADV DU PLESSIS PLAYS THE SECOND VIDEO', 'CONTENTS OF THE SECOND VIDEO', 'OP DIE VIDEO', 'SHOWING OF VIDEO']
# CONTINUES
# ['SCREENING OF VIDEO CONTINUES', 'COMMENTARY CONTINUES', 'SCREENING OF SECOND VIDEO CONTINUES', 'MR BERGER CONTINUES']
# NGQULUNGA
# ['T C NGQULUNGA', 'MS NGQULUNGA', 'THOLAKELE CATHERINE NGQULUNGA']
# MORUDU
# ['SCHEEPERS MORUDU', 'MR MORUDU', 'S MORUDU', 'MATLAKALA ELLEN MORUDU']
# EYCK
# ['JOHAN VAN EYCK', 'MR VAN EYCK', 'MNR VAN EYCK']
# CLOETE
# ['MS CLOETE', 'ROSALINE DESIREE CLOETE', 'MR CLOETE']
# MUHADI
# ['NGOMANDU AMOS MUHADI', 'MR MUHADI', 'NOGAMANDU AMOS MUHADI', 'NGAMANDU AMOS MUHADI']
# MUDAU
# ['PUMELANE LAWRENCE MUDAU', 'MR MUDAU', 'FRANS TUWANI MUDAU', 'ROSINA MUDAU', 'MS MUDAU']
# MAHVUNGA
# ['MRS MAHVUNGA', 'ROSINNAH MAHVUNGA', 'MS MAHVUNGA']
# MUNYAI
# ['LANGANANI FOSTER MUNYAI', 'ENNIE MUNYAI', 'THILWAIWI MUNYAI']
# MULAUDZI
# ['NNDWELENI MULAUDZI', 'FREDDIE JOSHUA MULAUDZI', 'JOSHUA LUFUNO MULAUDZI', 'MR MULAUDZI']
# MABENA
# ['MR MABENA', 'SIMLINDILE MABENA', 'DANIEL MNINDWA MABENA', 'TIMOTHY TONY MABENA']
# DANDALA
# ['MR DANDALA', 'GCINISIKO LAMONT DANDALA', 'GCINISIKO LAMONI DANDALA', 'GCINISIKO LAMONI DANDALA', 'BISHOP H M DANDALA']
# SIQHOLA
# ['NELSON NKOSINATHI SIQHOLA', 'MR SIQHOLA', 'N N SIQHOLA']
# MBELE
# ['JACK MBELE', 'MR MBELE', 'ISABELLA MBELE']
# MAZIBUKO
# ['MR MAZIBUKO', 'TIMOTHY STALS MAZIBUKO', 'MR J T MAZIBUKO', 'JOSEPH TITUS MAZIBUKO', 'VALLEY MAZIBUKO', 'MR V MAZIBUKO', 'NHLANHLA PETROS MAZIBUKO', 'MRS MAZIBUKO', 'THEMBELIHLE MAZIBUKO', 'MS MAZIBUKO', 'THEMBALIHLE MAZIBUKO', 'FANYANA MAZIBUKO']
# THOMAS
# ['MS THOMAS', 'ANDRE THOMAS', 'SUSANNA ELIZABETH THOMAS', 'MR THOMAS']
# BALOYI
# ['MACHIHLILE WILSON BALOYI', 'ABEL BAKGANE BALOYI', 'EDDIE BALOYI', 'SELINA MAKAO BALOYI']
# MOLETE
# ['MATSELENG MIRIAM MOLETE', 'MIRIAM MOLETE', 'MS M MOLETE', 'FLORENCE MOLETE', 'MS F MOLETE', 'MRS MOLETE', 'ANNA MNONO MOLETE', 'DANIEL MOLETE', 'MR MOLETE']
# MAGUBANE
# ['RUBEN MAGANGA DEBOGO MAGUBANE', 'RUBEN MAGANGA TEBOGO MAGUBANE', 'PETER MAGUBANE']
# MACHITJE
# ['MR MACHITJE', 'CHICHELA ESAU MACHITJE', 'CHICELA ESAU MACHITJE']
# SESELE
# ['MR SESELE', 'MRS SESELE', 'RANSEHU SYLVESTER BERNARD SESELE']
# MOSIA
# ['PHILLIP MOSIA', 'MR MOSIA', 'SOLOMON MOSIA', 'MAPHAKA PLAATJIE MOSIA']
# SNYDERS
# ['DANIEL BENJAMIN SNYDERS', 'MR SNYDERS', 'MNR SNYDERS']
# SOOKA
# ['MS SOOKA', 'Ms SOOKA', 'MRS SOOKA', 'MS Y SOOKA']
# MANTHATA
# ['MR MANTHATA', 'DR MANTHATA', 'MANTHATA', 'MR T MANTHATA']
# RANDERA
# ['DR RANDERA', 'MR RANDERA', 'DR FAZEL RANDERA', 'DOCTOR RANDERA']
# MABUZA
# ['MR MABUZA', 'MAMANE MABUZA', 'MRS MABUZA', 'NONSA NOBUHLE MABUZA', 'MS MABUZA', 'REV WESLEY MABUZA']
# SEROKE
# ['MS SEROKE', 'MRS SEROKE', 'MS JOYCE SEROKE', 'MISS SEROKE', 'MS JOY SEROKE', 'MISS JOY SEROKE', 'MR SEROKE', 'MOSIMANEGAPI SEROKE']
# MANANA
# ['KENNETH MANANA', 'MS MANANA', 'KELLINA MANANA', 'MR MANANA', 'SIPHO MANANA']
# MATHEBULA
# ['MR MATHEBULA', 'MRS MATHEBULA', 'DUKAKILE AGNES MATHEBULA', 'OUPA MATHEBULA']
# MATJILA
# ['MOTSHENTSHE JAN MATJILA', 'MR MATJILA', 'MRS MATJILA']
# MAYISA
# ['DOKKIE ELIAS MAYISA', 'MRS MAYISA', 'MAMATSHI L MAYISA', 'MR MAYISA', 'JOSIA MAYISA']
# MKHELE
# ['MRS MKHELE', 'DORA DZANANA MKHELE', 'MR MKHELE', 'FANWELL MKHELE']
# MNGADI
# ['MR MNGADI', 'REGINA NONTSIKELELO MNGADI', 'MLAMULI MNGADI']
# SIDZUMO
# ['NTOMBIZODUA SIDZUMO', 'MS SIDZUMO', 'S SIDZUMO']
# ALLY
# ['DR ALLY', 'MR ALLY', 'MY ALLY']
# RAMASHALA
# ['DR RAMASHALA', 'M RAMASHALA', 'MS RAMASHALA']
# SHABANGU
# ['MR SHABANGU', 'EDWARD SHABANGU', 'NKOSI NELSON SHABANGU']
# CRICHTON
# ['MS CRICHTON', 'MRS CRICHTON', 'JUNE CRICHTON', 'MISS CRICHTON']
# PETER
# ['COL PETER', 'ZINAKILE ERIC PETER', 'MBULELO LAWRENCE TOYO PETER', 'WAYILESE PETER', 'LULAMILE BASIE PETER']
# FINCA
# ['REV FINCA', 'REVD FINCA', 'MR BONGANI FINCA', 'MR FINCA', 'MRS FINCA', 'B FINCA']
# OELSCHIG
# ['MAJGENERAL MARIUS OELSCHIG', 'MARIUS OELSCHIG', 'MAJ OELSCHIG']
# MXOLI
# ['NTSIKELELO MXOLI', 'JANE MXOLI', 'MS MXOLI', 'NOMBUYISELO BEAUTY MXOLI', 'MRS MXOLI']
# MANGONA
# ['LORANCE MANGONA', 'MR MANGONA', 'MISS MANGONA']
# NZILANE
# ['NONGALIPHI LENHA NZILANE', 'MS NZILANE', 'MRS NZILANE']
# MGOJO
# ['DR MGOJO', 'MR MGOJO', 'REV MGOJO', 'DR K MGOJO', 'K MGOJO']
# OLIFANT
# ['SHADRACK THEKO OLIFANT', 'MRS OLIFANT', 'BROTHER OR MRS OLIFANT', 'MERIAM OLIFANT']
# MAGWAZA
# ['DR MAGWAZA', 'MRS MAGWAZA', 'MARIE ODENDAAL MAGWAZA', 'PROF MAGWAZA', 'PROFESSOR MAGWAZA']
# MORAKE
# ['BHAKI GEORGE MORAKE', 'EVELYN M MORAKE', 'MRS MORAKE', 'MS MORAKE', 'PATRICK MORAKE']
# WILDSCHUT
# ['MS WILDSCHUT', 'GLENDA WILDSCHUT', 'ME WILDSCHUT', 'MISS WILDSCHUT']
# NDIMA
# ['MR NDIMA', 'SAM NDIMA', 'MS NDIMA']
# ODENDAL
# ['CORNELIUS ADOLF JANSE ODENDAL', 'MNR ODENDAL', 'MR ODENDAL', 'MIKE ODENDAL']
# YAMILE
# ['MELFORT YAMILE', 'MR YAMILE', 'MR YAMILE']
# CHRICHTON
# ['JUNE CHRICHTON', 'MRS CHRICHTON', 'MS CHRICHTON']
# NTSWAYI
# ['MRS NTSWAYI', 'NOMAMASE NTSWAYI', 'XNIDISI NTSWAYI', 'MR NTSWAYI']
# KEKANA
# ['MRS KEKANA', 'PAULINA MASELEPE KEKANA', 'MS KEKANA']
# GALELA
# ['ZUKO GALELA', 'RITA GALELA', 'LENDISO RICHARD NDUMO GALELA', 'ALISHIA BUKIWE GALELA', 'MRS GALELA', 'WITNESS GALELA']
# JORDAN
# ['MR JORDAN', 'JOE THETHINENE JORDAN', 'MR TETINENE WADSWORTH JORDAN']
# SUKWANA
# ['MZWAMADODA DE VILLIERS SUKWANA', 'M DE V SUKWANA', 'MR DE V SUKWANA']
# THOLE
# ['NOMBULELO ELIZABETH THOLE', 'MS THOLE', 'NE THOLE']
# QUINN
# ['MR QUINN', 'MISS QUINN', 'MRS QUINN', 'PATRICIA QUINN PHILIP QUINN AND JANE QUINN']
# MSHENGU
# ['MRS MSHENGU', 'BEATRICE NIKIZIWE MSHENGU', 'MUSAWENKOSI MSHENGU']
# GOVENDER
# ['KRISH GOVENDER', 'PETER GOVENDER', 'SHADRACK GOVENDER']
# TURNER
# ['MRS FOWZIA TURNER', 'MS K J TURNER', 'KIM TURNER', 'FOWZIA TURNER']
# MHLAWULI
# ['NOMBUYISELO MHLAWULI', 'MHLAWULI', 'MRS MHLAWULI', 'MISS MHLAWULI', 'ROSEY NOCAWE MHLAWULI']
# TUTU
# ['ARCHBISHOP TUTU', 'REVEREND TUTU', 'CHAIRPERSON ARCHBISHOP TUTU', 'REV TUTU', 'A HYMN IS SUNG AND PRAYERS SAID BY REVEREND TUTU', 'REVD TUTU']
# ORR
# ['DR ORR', 'MS ORR', 'DR WENDY ORR', 'DR W ORR']
# ZOKWE
# ['NONCEBA BEAUTY ZOKWE', 'MRS ZOKWE', 'MS MANDI ZOKWE', 'ANSARAH NDABAKAZI ZOKWE']
# KOLITI
# ['MRS KOLITI', 'NONZAME ELIZABETH KOLITI', 'MS KOLITI', 'MR KOLITI']
# MADIKANE
# ['MR MTOZAMI MADIKANE', 'MS MADIKANE', 'NONKULULEKO NONYANISO GLADYS MADIKANE']
# MOSE
# ['MR MAKI MICHAEL MOSE', 'MR MOSE', 'MR LUNDI MOSE']
# GXIDI
# ['PATRICIA GXIDI', 'MRS GXIDI', 'P GXIDI']
# JAKO
# ['SHUMIKAZI SARA JAKO', 'MRS JAKO', 'S S JAKO']
# MARWEZU
# ['NOSIPHO BLOSSOM MARWEZU', 'MRS MARWEZU', 'N B MARWEZU']
# MJILA
# ['NOXOLO MJILA', 'MRS MJILA', 'N MJILA']
# SIWALE
# ['THEMBISA SIWALE', 'MS SIWALE', 'T SIWALE']
# LOLIWE
# ['NOSIPHO LOLIWE', 'NND LOLIWE', 'NONDLEKO NOLIFISI DINAH LOLIWE']
# MNGAZA
# ['VUYANI MNGAZA', 'MR MNGAZA', 'V MNGAZA']
# MTHETHWA
# ['MRS MTHETHWA', 'NOZIPHO MTHETHWA', 'NTOMBIKANINA MTHETHWA', 'JOSEPH SABELA MTHETHWA', 'BEAUTY MKHAJWA MTHETHWA', 'MILDRED MTHETHWA', 'NOTHI E MTHETHWA', 'MAKHOSEZWE MTHETHWA', 'GRETA MTHETHWA']
# KAKANA
# ['ZANYIWE ANGELINA NOSISI KAKANA', 'NOKUZOLA LENA NONHI KAKANA', 'BUTI JOHN KAKANA', 'MR KAKANA', 'MS N L N KAKANA']
# KOTI
# ['NOMBENQANA ALBERT KOTI', 'MR KOTI', 'MR KOTI']
# MENZI
# ['MR M MENZI', 'EDWARD GUGWANA MENZI', 'MBULELO MENZI', 'MR E G MENZI']
# SIKO
# ['NOMAKHWEZI GEORGINA SIKO', 'MAVIS SIKO', 'MRS SIKO', 'MS SIKO', 'EMILY SIKO', 'M SIKO']
# SOYA
# ['NOMILILE PHYLLIS TANDIWE SOYA', 'MRS SOYA', 'IVY NOTHANDEKILE SOYA', 'MONWABISI SOYA']
# TSILI
# ['MR TSILI', 'JONI TSILI', 'NOMANGESI TSILI', 'MISS TSILI']
# LUBOWSKI
# ['MS LUBOWSKI', 'MR LUBOWSKI', 'ANNALIZE LUBOWSKI', 'LUBOWSKI']
# GOBODO
# ['MS GOBODO', 'PHILISA PATRICIA TUMSE GOBODO', 'MR GOBODO']
# ZWENI
# ['NOMAKULA EVELYN ZWENI', 'DOUGLAS ZWENI', 'MALINGE ZWENI', 'MR ZWENI', 'MS ZWENI', 'MRS ZWENI']
# TINTO
# ['SENATOR TINTO', 'MR TINTO', 'CHRISTMAS TINTO']
# MALITI
# ['THOMZAMA MALITI', 'MS MALITI', 'MR MALITI']
# MLANGENI
# ['CATHERINE MLANGENI', 'SEPATI MLANGENI', 'MRS MLANGENI', 'MRS S MLANGENI']
# TIMOL
# ['HAWA TIMOL', 'MS TIMOL', 'MOHAMMED TIMOL', 'MR H TIMOL']
# TIRO
# ['M TIRO', 'MOLESENG ANNA TIRO', 'MS TIRO']
# SONAMZI
# ['NCAMISILI SONAMZI', 'NCAMISILE SONAMZI', 'MR SONAMZI']
# JOKA
# ['NCEBA JOKA', 'FLOIT JOKA', 'MR JOKA']
# MFAZWE
# ['MKOHNTO MFAZWE', 'MESHACK MFAZWE', 'DILIZA MAYFORD MFAZWE']
# MASETI
# ['MONWABISI MASETI', 'BEATRICE BRENDA MASETI', 'ZIXOLISILE MATTHEWS MASETI']
# MABIJA
# ['PHAKAMILE HARRY MABIJA', 'SYLVIA MABIJA', 'SHIRLEY MABIJA', 'MS MABIJA', 'MABIJA', 'COMPLAINANT SYLVIA NONTSIKELELO MABIJA', 'COMPLAINANT MARYJANE THEMBILE MABIJA']
# MOKONE
# ['IZAKIEL MOKONE', 'ELIZABETH MEADE MOKONE', 'MS MOKONE']
# MOKHUWANE
# ['CHRISTOPHER MOKHUWANE', 'MABU MOKHUWANE', 'MS MOKHUWANE', 'STATEMENT FROM MABU MOKHUWANE']
# KOOPMAN
# ['ALAKIE KOOPMAN', 'SIENA KOOPMAN', 'MS KOOPMAN', 'ME KOOPMAN']
# MOLELEKI
# ['SYLVIA VUIZWA MOLELEKI', 'SYLVIA MOLELEKI', 'MS MOLELEKI']
# KGATIWANE
# ['TOMMY KGATIWANE', 'AUBREY KGATIWANE', 'GRACE KGATIWANE', 'ME KGATIWANE']
# BADI
# ['ELIZABETH NOWAKHE BADI', 'ERIC BADI', 'MRS BADI', 'MR BADI']
# GUZANA
# ['NOMZI VIVIE GUZANA', 'MRS GUZANA', 'MRS GUZANA']
# DYEVANA
# ['N DYEVANA', 'NENESA DYEVANA', 'MS DYEVANA']
# SITHABATHABA
# ['M SITHABATHABA', 'NOMBUKWANE SITHABATHABA', 'MR SITHABATHABA']
# MBELEKANA
# ['NOBE SUTHU PATIENCE MBELEKANA', 'MRS MBELEKANA', 'MRS MBELEKANA']
# NGQANDU
# ['RONALD NGQANDU', 'MR NGQANDU', 'RM NGQANDU', 'R NGQANDU', 'MR NGQANDU']
# BANI
# ['JACKSON MALIBISHE BANI', 'MR BANI', 'MR BANI']
# NONGENA
# ['DANIEL PAULOS NONGENA', 'MR NONGENA', 'R NONGENA', 'JOHNSON NONGENA', 'J NONGENA']
# SKIET
# ['MASIXOLE SKIET', 'M SKIET', 'MR SKIET']
# MNYAPE
# ['NOPEPENGI MARGARET MNYAPE', 'MAKALAN MNYAPE', 'MRS MNYAPE', 'MR MNYAPE']
# NGECE
# ['NOMBUYISELO NTSIBA NGECE', 'MTHETHO NGECE', 'MRS NGECE', 'MR NGECE']
# RHOJI
# ['MR RHOJI', 'VUSANTE STANLEY RHOJI', 'NOHOMBILE RHOJI', 'MRS RHOJI']
# SOLANI
# ['NTSIKELO WELLINGTON SOLANI', 'MR SOLANI', 'SOLANI', 'N W SOLANI', 'NODOLI LILLIAN SOLANI']
# PATSA
# ['ZODWA PATSA', 'MRS PATSA', 'MRS PATSA']
# MATHIBA
# ['MR MATHIBA', 'MOSEMANE PETRUS MATHIBA', 'MRS MATHIBA', 'MARGARET MATHIBA']
# MMOLAWA
# ['MRS MMOLAWA', 'MERIAM MMOLAWA', 'MR MMOLAWA', 'EZEKIEL MMOLAWA']
# MOGAPI
# ['ANNIE K MOGAPI', 'MOLAPISI PETRUS MOGAPI', 'BEN TIGORAMBO MOGAPI']
# RASMENI
# ['MR RASMENI', 'MRS RASMENI', 'MANDLENKOSI S RASMENI']
# TLWAELO
# ['MRS TLWAELO', 'IRENE MODISE TLWAELO', 'MR TLWAELO']
# MAUDA
# ['MR MAUDA', 'FRANS MAUDA', 'MS MAUDA']
# FANI
# ['MS FANI', 'MR FANI', 'MRS FANI']
# NDABA
# ['NTOMBENTSUNDU GLADYS NDABA', 'EUNICE NOZIZWE NDABA', 'MRS NDABA']
# NDABAMBI
# ['BUSISIWE NDABAMBI', 'PHILDA VIOLET NDABAMBI', 'PV NDABAMBI', 'B NDABAMBI']
# PATHEKILE
# ['CHIEF BUKRULA PATHEKILE', 'MS KHETHIWE PATHEKILE', 'CHIEF PATHEKILE', 'MRS PATHEKILE', 'MR PATHEKILE']
# NONKONYANE
# ['ADV MVELO NONKONYANE', 'ADV NONKONYANE', 'MR NONKONYANE']
# MAKHOKHOBA
# ['NDENGEZI MAKHOKHOBA', 'NANTAGELO MAKHOKHOBA', 'MR MAKHOKHOBA', 'MRS MAKHOKHOBA', 'MS MAKHOKHOBA']
# SEKHAULELO
# ['THALITHA SEKHAULELO', 'MS THALITHA SEKHAULELO', 'MS SEKHAULELO']
# MODISE
# ['MR MODISE', 'LUKAS M MODISE', 'MR MODISE', 'JOE MODISE', 'THANDI MODISE']
# MABALANE
# ['MS MABALANE', 'PULANE G MABALANE', 'S MABALANE', 'PHILLIP MABALANE']
# MOKOTEDI
# ['VIOLET MOKOTEDI', 'MS MAGGIE MOKOTEDI', 'MS VIOLET MOKOTEDI', 'MS VIOLET MOKOTEDI']
# MOLAOLWA
# ['MR E B MOLAOLWA', 'EDWIN B MOLAOLWA', 'MR MOLAOLWA']
# YAKWE
# ['MS MARTHA YAKWE', 'MARTHA YAKWE', 'MS YAKWE']
# MASONDO
# ['TRYPHINA MASONDO', 'MR MASONDO', 'MDUDUZI MASONDO', 'MRS MASONDO']
# NIEKERK
# ['CAPT VAN NIEKERK', 'GERHARD VAN NIEKERK', 'MR VAN NIEKERK']
# LEKHULENI
# ['MR LEKHULENI', 'MR SKINOD LEKHULENI', 'MRS LEKHULENI']
# MAHLABANE
# ['MRS MAHLABANE', 'NQAZI FLORA MAHLABANE', 'MR MAHLABANE']
# MALOMA
# ['SIBONGILE MALOMA', 'MS MALOMA', 'MR MALOMA']
# NGOMANE
# ['MRS NGOMANE', 'SAMARIAH NORAH NGOMANE', 'MR NGOMANE', 'SAMSON NGOMANE']
# MAPHUMULO
# ['MZOTHULI MAPHUMULO', 'MRS T MAPHUMULO', 'MRS N MAPHUMULO', 'THOBEKILE MAPHUMULO and NOMBULELO MAPHUMULO', 'PETER MAPHUMULO']
# MHLUNGU
# ['JABULISILE MHLUNGU', 'MR MHLUNGU', 'SIBUSISO MHLUNGU', 'MRS MHLUNGU', 'LINDIWE MHLUNGU']
# NCHABELENG
# ['MRS NCHABELENG', 'MATSATSI GERTRUDE NCHABELENG', 'MORRIS NCHABELENG', 'MR NCHABELENG']
# PAULSEN
# ['LOUISA PAULSEN', 'MS PAULSEN', 'MR PAULSEN']
# KLEYN
# ['MR KLEYN', 'MNR KLEYN', 'JOHN JOHANNES GEORGE CHRISTOFFEL KLEYN', 'JOHANNES GEORGE CHRISTOFFEL KLEYN']
# LIEBENBERG
# ['MR LIEBENBERG', 'MS LIEBENBERG', 'MNR LIEBENBERG', 'WILLIAM RUDOLPH LIEBENBERG', 'WILLIAM RUDOLF LIEBENBERG']
# BEKWA
# ['MRS BEKWA', 'BANDLAKAZI JANE BEKWA', 'MR BEKWA']
# TSHANGA
# ['MRS TSHANGA', 'MRS R TSHANGA', 'MRS T TSHANGA']
# KHESWA
# ['FELIX THULANI KHESWA', 'MRS EMMA KHESWA', 'ANNA MADIEMI KHESWA']
# KAMATI
# ['NTOMBIZIDWA MARTHA KAMATI', 'NM KAMATI', 'S KAMATI']
# BUSANG
# ['NTOMBENKULU BUSANG', 'MRS BUSANG', 'MS BUSANG']
# MGWENYA
# ['MS MGWENYA', 'MRS MGWENYA', 'MR MGWENYA']
# SONO
# ['MR N SONO', 'CAROLINE SONO', 'NICODEMUS SONO', 'MR SONO', 'MRS SONO']
# MASISA
# ['MS MASISA', 'SELINA MASISA', 'MRS MASISA']
# NJIKELANI
# ['TETISWA NJIKELANI', 'MRS NJIKELANI', 'MS NJIKELANI']
# CALU
# ['VINCENT LUNGILE CALU', 'MR CALU', 'V CALU']
# GQUBULE
# ['FUNDILE LAWRENCE GQUBULE', 'MR GQUBULE', 'G GQUBULE']
# JACKSON
# ['KUMVUSELE WILLIAM JACKSON', 'MR JACKSON', 'MS JACKSON']
# RAMATHE
# ['WENDY SIZEKA RAMATHE', 'MS RAMATHE', 'W S RAMATHE']
# DLADLAMBA
# ['MS DLADLAMBA', 'ANNA MATAMELA DLADLAMBA', 'MR DLADLAMBA']
# MUKOSI
# ['MR MUKOSI', 'NTOMBIZANDILE MUKOSI', 'MRS MUKOSI', 'MS MUKOSI']
# TSHIVHASE
# ['MS TSHIVHASE', 'SOPHIA NTSUDENI TSHIVHASE', 'SN TSHIVHASE']
# CHAKA
# ['MRS CHAKA', 'MR CHAKA', 'MATUMO JOSEPHINA CHAKA']
# XHAMFU
# ['MR XHAMFU', 'MRS XHAMFU', 'JACKSON XHAMFU']
# DIPPA
# ['MRS DIPPA', 'THASHIMA GLORIA DIPPA', 'PULENG DIPPA']
# VILJOEN
# ['MR VILJOEN', 'GEN VILJOEN', 'GEN CONSTAND VILJOEN', 'CONSTAND VILJOEN']
# BAHUME
# ['NATION NKOSANE BAHUME', 'MARIA BAHUME', 'MS BAHUME']
# JOSEPH
# ['SARALINE JOSEPH', 'MRS JOSEPH', 'ME JOSEPH']
# MAKGANYE
# ['L MAKGANYE', 'L MAKGANYE', 'LIZO MAKGANYE']
# MOKGATLANYANE
# ['NR MOKGATLANYANE', 'JOHN MOKGATLANYANE', 'MR MOKGATLANYANE']
# GOOSEN
# ['MR GOOSEN', 'DR GOOSEN', 'ADRIAAN JACOBUS GOOSEN']
# CRAFFORD
# ['SAREL DU PLESSIS CRAFFORD', 'MAJ CRAFFORD', 'MAJOR CRAFFORD']
# KNOBEL
# ['DANIEL PETER KNOBEL', 'DR KNOBEL', 'COUNSEL FOR KNOBEL', 'NEIL KNOBEL', 'MR KNOBEL', 'GENERAL M KNOBEL']
# RATEMANE
# ['SOLLY RATEMANE', 'PROF RATEMANE', 'DR RATEMANE']
