# %%
import json
import glob

files = glob.glob(f"../data/data_saha/*/*/*.json")
speakers = []
for filename in files:
    with open (filename, "r") as f:
        data = json.load(f)
    tmp = data["header"]["speakers"]
    for t in tmp:
        if "(" in t:
            print (t)
        speakers.append(t)
speakers = list(set(speakers))
speakers.sort()
print (len(speakers))
with open ("../data/all_speakers.json", "w") as f:
    json.dump(speakers, f, indent=4)
# Out:
# 5061

# %%
5757

# %%
speakers
# Out:
# ['<UNKNOWN>',
#  'A E VERWEY',
#  'A J G ERWEE',
#  'A MTHEMBU',
#  'A NOFOMELA',
#  'A ON RESUMPTION',
#  'AARON MOKGATLE',
#  'AARON SIMON THABO',
#  'AARON ZIBUSE ZULU',
#  'ABDULHAY JASSAT',
#  'ABEL BAKGANE BALOYI',
#  'ABEL BOESAK',
#  'ABEL KUTU',
#  'ABEL MULADY',
#  'ABEL OUPA KHOTLE',
#  'ABEL OUPA LERATO KHOTLE',
#  'ABEL PHELE',
#  'ABOOBAKER ISMAIL',
#  'ABRAHAM CHRISTOFFEL FOURIE',
#  'ABRAHAM LIEBRECHT MYBURGH',
#  'ABRAHAM MOTHUPHI',
#  'ABRAM DIDI MAUMAKWE',
#  'ABRAM VAN ZYL',
#  'ACELINA MADLAMINI NDZOYANA',
#  'ADELAIDE KHANYISILE MATANDELA',
#  'ADELAIDE MOKETE BUNGANE',
#  'ADELAIDE NGCOBO',
#  'ADJOURNS RESUMES',
#  'ADOLPHUS CELE',
#  'ADRIAAN JACOBUS GOOSEN',
#  'ADRIAAN SMUTS',
#  'ADRIAAN VAN STRAATEN',
#  'ADRIAAN VLOK',
#  'ADRIAN CHARLES OFARRELL',
#  'ADRIAN DAVID BAKER',
#  'ADRIAN STEVEN ROSSLEE',
#  'ADRIANA JOHANNA CHRISTINA DE WET',
#  'ADV',
#  'ADV BEMBRIDGE',
#  'ADV BOOYENS',
#  'ADV BOSMAN',
#  'ADV C BOOYENS',
#  'ADV CHRIS DE JAGER',
#  'ADV COLLETT',
#  'ADV D POTGIETER',
#  'ADV DE JAGER',
#  'ADV DE KLERK',
#  'ADV DE LA HOOP',
#  'ADV DONEN',
#  'ADV DU PLESSIS',
#  'ADV FORD',
#  'ADV GCABASHE',
#  'ADV GOZA',
#  'ADV GOZO COMMITTEE',
#  'ADV GRIMBEECK',
#  'ADV HIEMSTRA',
#  'ADV J MOSES',
#  'ADV JANSEN',
#  'ADV JORDI',
#  'ADV KUNE',
#  'ADV KUNY',
#  'ADV LAMEY',
#  'ADV LOURENS',
#  'ADV LOUW',
#  'ADV MADASA',
#  'ADV MALAN',
#  'ADV MATHANA',
#  'ADV MATUIS',
#  'ADV MEMANI',
#  'ADV MOJAPELO',
#  'ADV MOTATA',
#  'ADV MTHEMBU',
#  'ADV NTSEBEZA',
#  'ADV NYOKA',
#  'ADV PATEL',
#  'ADV POTGIETER',
#  'ADV PRINSLOO',
#  'ADV PRIOR',
#  'ADV PRIOR COMMITTEE',
#  'ADV SANDI',
#  'ADV SIBANYONI',
#  'ADV SIGIDI',
#  'ADV SIGODI',
#  'ADV SNYMAN',
#  'ADV SOGODI',
#  'ADV STEENKAMP',
#  'ADV TEE',
#  'ADV THABETHA',
#  'ADV THABETHE',
#  'ADV THSONGWENI',
#  'ADV TSHONGWENI',
#  'ADV VALUS',
#  'ADV VAN DER VKV',
#  'ADV VAN DER WALDT',
#  'ADV VAN DER WALT',
#  'ADV VAN DER WALT COMMISSION ON MERITS OF CASE',
#  'ADV VAN SCHALWYK',
#  'ADV VAN ZYL',
#  'ADV VISSER',
#  'ADV VISSER TO MRS MOLOI',
#  'ADVARENDSE',
#  'ADVDE JAGER',
#  'ADVSIGODI',
#  'AFFIRMATION ADMINISTERED TO PANEL OF ANC',
#  'AG',
#  'AGGIE SHOKE',
#  'AGNES GOUNDEN',
#  'AGNES HLOMELA',
#  'AGNES MANYISA',
#  'AGNES NHLAPHO',
#  'AGNESS MAMSARENI MAGAWANA',
#  'AHMED MOOSA',
#  'AJUDGE',
#  'AKINA MAGODA',
#  'ALAKIE KOOPMAN',
#  'ALAN TYANI',
#  'ALBERT AMANDLA NANGALEMBE',
#  'ALBERT MHANDE NSIBANDE',
#  'ALBERT NKUNA',
#  'ALBERT SBANGELISO MASEKO',
#  'ALBERTINA NOMBOYSELA GOBIZEMBE',
#  'ALBERTINA NOMFANELEKO MAKIWANE',
#  'ALBERTINA SISULU',
#  'ALETTA MAGRIETA ROUX',
#  'ALETTA RAMOSEPELE',
#  'ALEX BEKHANI HLONGWANE',
#  'ALFAS MABORE NDLOVU',
#  'ALFIUS JACKSON JEKE',
#  'ALFRED BANGIZWE MNIKATHI',
#  'ALFRED DAYILE',
#  'ALFRED KANGALE MATELO',
#  'ALFRED MANDLA MHLAMBO',
#  'ALFRED SIKILELE MTHEMBU',
#  'ALICE NOMBEKO MFENQE',
#  'ALINA MALEF MOFOKENG',
#  'ALINA VILAKAZI',
#  'ALISHIA BUKIWE GALELA',
#  'ALIYA ANNIE SEGAGE',
#  'ALL',
#  'ALL FIVE WITNESSES SWORN IN',
#  'ALL SEVEN WITNESSES SWORN IN',
#  'ALLEGED PERPETRATORS',
#  'ALLI MAZIYA',
#  'ALMOND BUTANA NOFOMELA',
#  'ALMOND NOFOMELA',
#  'ALONE',
#  'ALPHEUS DUMUSANE MSIBI',
#  'ALVINA NGCOBO',
#  'ALWINUS MRALASI',
#  'ALZINA MKAZA LUTHULI',
#  'AMANDA EUNICE MAGWACA WONGA BILLIE',
#  'AMANDA JANE ELIZABETH CLEMENSON',
#  'AMBROSE ARMSTRONG ROSS',
#  'AMBROSE SHEZI',
#  'AMELIA DYANTYI',
#  'AMELIA MOLAPO',
#  'AMELIA NOMATSHAWE JOZI',
#  'AMINA ABRAHAMS',
#  'AMINA DESAI',
#  'AMNESTY',
#  'AMOS DIKO',
#  'AMOS MAZIZI KANGO',
#  'AMOS NGOBESE',
#  'ANAH MTHINKHULU',
#  'AND',
#  'AND FOR THE ILLEGAL POSSESSION OF A STECHKIN',
#  'ANDERSON MPENDELO LIZO',
#  'ANDILE GOLA',
#  'ANDILE JACK',
#  'ANDILE NDEMBU',
#  'ANDILE PHILLIP BLAAUW',
#  'ANDILE SHICEKA',
#  'ANDILE TABENA',
#  'ANDRE FRANCOIS VISSER',
#  'ANDRE GROBBELAAR',
#  'ANDRE KRITZINGER',
#  'ANDRE MARANDOM MALAN',
#  'ANDRE RENIER SWART',
#  'ANDRE THOMAS',
#  'ANDREA JEANNETTE LANGFORD',
#  'ANDREAS MPHANI SITHOLE',
#  'ANDREW PETER VAN WYK',
#  'ANDRIES BONGNKOSI NTJALI',
#  'ANDRIES CORNELIUS OOSTHUIZEN',
#  'ANDRIES DAVID JACOBUS VAN TONDER',
#  'ANDRIES HENDRIK ALBERTS',
#  'ANDRIES JOHANNES GERHARDUS ERWEE',
#  'ANDRIES KGOBADI',
#  'ANDRIES KOTO',
#  'ANDRIES MATANZIMA NOSENGA',
#  'ANDRIES MOLAOA',
#  'ANDRIES MOZIKEFANI GAMEDE',
#  'ANDRIES NDEBELE',
#  'ANDRIES SIBOKWAKE SITHOLE',
#  'ANDRIES STEPHANUS KRIEL',
#  'ANGELINA RAMPO NOMAVUKA',
#  'ANGELINA SIBONGILE NDLOVU',
#  'ANN BERNSTEIN',
#  'ANN MACKAY',
#  'ANNA HELENA JERLING',
#  'ANNA MADIEMI KHESWA',
#  'ANNA MASAMUEL KUTUMELA',
#  'ANNA MATAMELA DLADLAMBA',
#  'ANNA MNONO MOLETE',
#  'ANNA NDLOVU',
#  'ANNA NOMTANDA NDLOVU',
#  'ANNALIZE LUBOWSKI',
#  'ANNE ELIZABETH CLACKERS',
#  'ANNEXURE A',
#  'ANNEXURE JPD',
#  'ANNIE K MOGAPI',
#  'ANNIE MONTSO',
#  'ANNIE PHAHLANE',
#  'ANNMARIE WALLACE',
#  'ANOTHER PANEL MEMBER',
#  'ANSARAH NDABAKAZI ZOKWE',
#  'ANSWER',
#  'ANTHONY LODA XABA',
#  'ANTHONY MANDANZELA',
#  'ANTHONY MOBELE',
#  'ANTHONY THOZAMILE NTONI',
#  'ANTOINETTE MALAZA',
#  'ANTOINETTE MUNDAU',
#  'ANTOINETTE SITHOLE',
#  'ANTON PRETORIUS',
#  'ANTONY MACI',
#  'AON',
#  'AON RESUMPTION',
#  'AP AN WYK',
#  'AP VAN WYK',
#  'APPLAUSE',
#  'APPLICANT',
#  'APPLICANTS',
#  'APPLICATION NO',
#  'ARCHBISHOP T W NTONGANA',
#  'ARCHBISHOP TUTU OPENS THE HEARING WITH A PRAYER',
#  'ARCHIE KHUMALO',
#  'ARGUMENT',
#  'ARMSCOR SPEAKER',
#  'ARREST AND INCARCERATION',
#  'ARTHUR LOLLAN',
#  'ASHFORD TRIKAMJEE',
#  'ASHLEY MURPHY MASIL',
#  'ASSAULT AND DISAPPEARANCE',
#  'ATHLONE HEARING WESTERN CAPE PROVINCE',
#  'ATTEMPTED MURDER',
#  'ATTORNEY',
#  'ATTORNEY GEN W JURGENS',
#  'AUBREY KGATIWANE',
#  'AUBREY MATLEMA MAILE',
#  'AUBREY MOKOENA',
#  'AUDIENCE',
#  'AUDIENCE IS CLAPPING THEIR HANDS',
#  'AUDIENCE MEMBER',
#  'AUDREY CHAPMAN',
#  'AUERBACH',
#  'AWB',
#  'AZHAR CACHALIA',
#  'AZWIFARWI CARLSON NETSHIVALE',
#  'B AMNESTY',
#  'B CROSS',
#  'B J MPONDO',
#  'B MBALO',
#  'B MDINGI',
#  'B NDABAMBI',
#  'B V MBAMBO',
#  'BABEKHILE SHANDU',
#  'BABY LANGA',
#  'BACKGROUND',
#  'BAFANA EDDIE KHUMALO',
#  'BAFANA GONZWEIZA MHLABA',
#  'BAFANA GONZWEIZE MHLABA',
#  'BAFO GIFT NGQUNGE',
#  'BAJABULILE NZAMA',
#  'BALEKA MBETHE',
#  'BAND DAG BAND KANT B MIDDEL VAN BAND',
#  'BANDLAKAZI JANE BEKWA',
#  'BAPTIST UNION CONVENTION',
#  'BAREND STRIJDOM',
#  'BAREND THABISO MONO',
#  'BARNABAS MBULELO KEKENI NDLELENI',
#  'BARNEY GLAJAWO',
#  'BASHITSHILE MQANTI MASIKANE',
#  'BASIL DUMISANE MAFU',
#  'BASSIE NZIKIZI MKHUMBUZI',
#  'BASSON',
#  'BATANDWA GODLO',
#  'BATHINI NGCOBO',
#  'BAYENI ANNIE SILINDA',
#  'BCOMMITTEE RESUMES',
#  'BEATEN',
#  'BEATING',
#  'BEATRICE BRENDA MASETI',
#  'BEATRICE NIKIZIWE MSHENGU',
#  'BEAUTY LULAMA MBIXANA',
#  'BEAUTY MKHAJWA MTHETHWA',
#  'BEAUTY MTSHAKAZANA',
#  'BEAUTY NTULI',
#  'BEGINNING OF TESTIMONY IS MISSING',
#  'BEGINS',
#  'BEKABANTU QALANYOBE',
#  'BEKHISISO ALEX KHUMALO',
#  'BEKI XABA',
#  'BELINA RATEFANE',
#  'BELINDA MDLALOSE',
#  'BEN KGOATHE',
#  'BEN MASISO',
#  'BEN TIGORAMBO MOGAPI',
#  'BENEDICTA BUSISIWE NGOBANI',
#  'BENJAMIN BRODE',
#  'BENJAMIN CHOLOTA',
#  'BENJAMIN MVUYISI YOYO',
#  'BENJAMIN POGRUND',
#  'BENNET MNYAKA NDABE',
#  'BENNET SIBAYA',
#  'BENNETTE NDYUNDYU JACK',
#  'BENSON VULINDLELA NSIMBI',
#  'BERGER',
#  'BERNARD BONAKELE JACOBS',
#  'BERNARD MAKGABO NGOEPE',
#  'BERNARD MKHIZE',
#  'BERNARD MWELASE',
#  'BERNICE JAKILA',
#  'BERTRAM OSWALD MOGGEE',
#  'BERTWELL BHEKI NDLOVU',
#  'BESSIE MDODA',
#  'BETH SAVAGE',
#  'BETHUEL MONDLI ZUMA',
#  'BETHUEL TOBILANE NKUNKUMA',
#  'BETTINA MDLALOSE AND THANDI MDLALOSE',
#  'BETTY LALIWE LOWAPE',
#  'BETTY NCANYWA',
#  'BETTY SKHOSANA',
#  'BETTY SKOSANA',
#  'BEULIN ISAAKS',
#  'BEYERS NAUDE',
#  'BHAKI GEORGE MORAKE',
#  'BHEKI ALFIUS NZAMA',
#  'BHEKI F MBUYAZI',
#  'BHEKI KHATHIDE',
#  'BHEKI NTULI',
#  'BHEKINKOSI MKHAKLAZENI MKHIZE',
#  'BHEKINKOSI MKHIZE',
#  'BHEKISISA ALEX KHUMALO',
#  'BHEKISIZWE PROF MBANJWA',
#  'BIKWAPHI MARTHA MTHIMUNYE',
#  'BISHOP DLAMINI',
#  'BISHOP KEVIN DOWLING',
#  'BISHOP MARTIN MORRISON',
#  'BISHOP MICHAEL NUTALL',
#  'BISHOP RETIEF',
#  'BISHOP STOREY',
#  'BISHOP ZAMABUHLE',
#  'BMR',
#  'BOBBY GODSELL NICK SEGAL ADRIAN DU PLESSIS',
#  'BOKVELA THOMAS PHULULA',
#  'BONAKELE BHAYI',
#  'BONAKELE HORATIUS JWAMBE',
#  'BONGA KHUMALO',
#  'BONGANE KUALA',
#  'BONGANI BUTHELEZI',
#  'BONGANI CHRISTOPHER KHUMALO',
#  'BONGANI FINCA',
#  'BONGANI GOLDEN MALEVU',
#  'BONGANI KHUMALO',
#  'BONGANI MAJOLA',
#  'BONGANI NKOSI',
#  'BONGANI NONDULA',
#  'BONGANI VICTOR RADEBE',
#  'BONGANI WILBERFORCE KHABA',
#  'BONGENI ALSON MAJOLA',
#  'BONGINKOSI AARON MZOBE',
#  'BONGINKOSI DLAMINI',
#  'BONGINKOSI GABRIEL MAKHOBA',
#  'BONGIWE GLORIA SKEPU',
#  'BONGNKOSI ELVIS ZULU',
#  'BONISWA ELSIE KHETHWA',
#  'BORAINE',
#  'BOROWSKY MASILELA',
#  'BOTHA',
#  'BOY VUSIMUZI GWAMANDA',
#  'BOYCE MTYOBILE',
#  'BOYCE NQONO',
#  'BRIAN CLIFFORD THOBEJANE',
#  'BRIAN GCINA MKHIZE',
#  'BRIAN PHINEAS PHOSIWA',
#  'BRIAN QUNA MKHIZE',
#  'BRIAN VICTOR MITCHELL',
#  'BRIEF ADJOURNMENT',
#  'BRIEFER',
#  'BRIG',
#  'BRIG CRONJE',
#  'BRIG FICHLER',
#  'BRIG HERTZOG LERM',
#  'BRIG MKHWANAZI',
#  'BRIG PHITLA',
#  'BRIG SIMANDLA',
#  'BRIGADIER J L J VAN RENSBURG',
#  'BRINK',
#  'BROTHER OR MRS OLIFANT',
#  'BRUNO SKHOSANA',
#  'BUKA PINZI',
#  'BUKIWE MAUD MPONGOSHE MUTIWE NELLIE MARWANQANA THANDIWE MARGARET MDLANKOMO',
#  'BUKULA',
#  'BULUKAZI ELSIE GEORGE',
#  'BULWANA VAALTYN',
#  'BUMBUMONT GOMERES THEMBISO KHUBEKA',
#  'BUSHY PETROS VANTYU',
#  'BUSISISWE MOKOENA',
#  'BUSISIWE E XABA',
#  'BUSISIWE NDABAMBI',
#  'BUSISIWE NKOSI',
#  'BUSISO XABA',
#  'BUSIZIWE ANTOINETTE ZUMA',
#  'BUTANA ALMOND NOFOMELA',
#  'BUTI JOHN KAKANA',
#  'BUTIKI JOHN KIBI',
#  'BUTINYANE SIMON SESEDINYANE',
#  'BUYELE PATIENCE ZUNGUMTHEMBU',
#  'BUYELWA INNOCENTIA PLAATJIES',
#  'BUYISILE SAMUEL SANGOTSHA',
#  'BUYISWA MARGARET CEKISANI',
#  'BUYISWA PATIENCE BHOTO',
#  'C A VAN DER WESTHUIZEN',
#  'C S HEYNEKE',
#  'CA VAN DER WESTHUIZEN',
#  'CAMP MENTZ',
#  'CANNOT HEAR MS GOBODO AT ALL',
#  'CAPE',
#  'CAPE MENTZ',
#  'CAPT BOKABA',
#  'CAPT CLAYTON',
#  'CAPT KEKANE',
#  'CAPT MENTZ',
#  'CAPT VAN NIEKERK',
#  'CAPTAIN SNYMAN',
#  'CAPTAIN VILJOEN',
#  'CAREL HENDRICKS MEIRING',
#  'CAREL HENDRIK MEIRING',
#  'CARL CASTELING BOTHA',
#  'CAROLINA SINKEPENG MOKOENA',
#  'CAROLINE SONO',
#  'CASE',
#  'CASE NO',
#  'CASPER ADRIAAN VAN DER WESTHUIZEN',
#  'CATHERINE MLANGENI',
#  'CECILIA PUTUNYWA NGETE',
#  'CELESTE MORRISON',
#  'CELTA MOHATLA',
#  'CETYIWE ELEANOR PIKA',
#  'CHAIRPERSON',
#  'CHARITY KONDILE',
#  'CHARLES ALEXANDER MATHER',
#  'CHARLES ALFRED ZEELIE',
#  'CHARLES MICHAEL SKOSANA',
#  'CHARLES MOKGATLE',
#  'CHARLES VAN REMOORTERE',
#  'CHARLES ZWANE',
#  'CHARMAINE JACOBS',
#  'CHERYL EILEEN LOOTS',
#  'CHESTER RAGWALA',
#  'CHICHELA ESAU MACHITJE',
#  'CHIEF BUKRULA PATHEKILE',
#  'CHIEF MARAI',
#  'CHIEF PATHEKILE',
#  'CHILE FAMILY',
#  'CHINOANE SIMON FARISANI',
#  'CHIPIWA ANTHONY MAHUMELA',
#  'CHRIS EVERSON',
#  'CHRIS MBKELA',
#  'CHRIS STALTZ CHRISTO SWART',
#  'CHRISTIAAN SIEBERT RORICH',
#  'CHRISTIAN PETER MEYER',
#  'CHRISTINA BUTHULEZI',
#  'CHRISTMAS TINTO',
#  'CHRISTO PETRO DEETLEFS',
#  'CHRISTOFFEL PIERRE VAN DER WESTHUIZEN',
#  'CHRISTOPHER MOKHUWANE',
#  'CHRISTOPHER NGCOBO',
#  'CLARA JABHILE KHUMALO',
#  'CLEMENT KHEHLANA GXABU',
#  'CLEMENT MASEMOLA',
#  'CLIFFORD MENDISI SIYOLO AND EPHRAIM NGCOBO',
#  'CLIVE DERBY LEWIS',
#  'CLIVE DERBYLEWIS',
#  'CLIVE MAHLAULI MAKHUBU',
#  'CLIVE MHLAULI MAKHUBU',
#  'CLLR ERLEIGH',
#  'CLOSING STATEMENT',
#  'COETZEE',
#  'COL DE JAGER',
#  'COL LOOTS',
#  'COL MKOSANA',
#  'COL PETER',
#  'COL SCHOBESBERGER',
#  'COL SHOBESBERGER',
#  'COL VENTER',
#  'COL ZENE',
#  'COLIN ANTHONY PECKENHAM ROBERTSHAW',
#  'COLLEEN JUDY WHITE',
#  'COLSON TEBOGO BEEA',
#  'COMBRINCK J',
#  'COMMENCEMENT OF TAPE B',
#  'COMMENT',
#  'COMMENTARY',
#  'COMMENTARY CONTINUES',
#  'COMMISSION ADJOURNS',
#  'COMMISSION ADJOURNS FOR LUNCH',
#  'COMMISSION ADJOURNS FOR LUNCH UNTIL',
#  'COMMISSION ADJOURNS FOR MINUTES ON RESUMPTION',
#  'COMMISSION ADJOURNS FOR TEA ON RESUMPTION',
#  'COMMISSION ADJOURNS FOR TEA UNTIL',
#  'COMMISSION ADJOURNS UNTIL A DATE TO BE DECIDED',
#  'COMMISSION ADJOURNS UNTIL JANUARY',
#  'COMMISSION ADJOURNS UNTIL THE',
#  'COMMISSION ADJOURNS UNTIL TWO OCLOCK',
#  'COMMISSION ADJOURS FOR LUNCH',
#  'COMMISSION CLOSES WITH NATIONAL ANTHEM',
#  'COMMISSION COMMENCES WITH PRAYERS',
#  'COMMISSION RESUMES',
#  'COMMISSIONER',
#  'COMMITTEE',
#  'COMMITTEE ADJOURNS',
#  'COMMITTEE ADJOURNS UNTIL',
#  'COMMITTEE ADJOURNS UNTIL TOMORROW MORNING',
#  'COMMITTEE ADJOURNS UNTIL TWO OCLOCK',
#  'COMMITTEE DISCUSSING',
#  'COMMITTEE MEMBER',
#  'COMMMENTARY',
#  'COMPANION',
#  'COMPLAINANT MARYJANE THEMBILE MABIJA',
#  'COMPLAINANT SYLVIA NONTSIKELELO MABIJA',
#  'COMRADES',
#  'CONCLUSION',
#  'CONRAD NKUNA',
#  'CONSTANCE MSONI',
#  'CONSTAND VILJOEN',
#  'CONTENTS OF THE SECOND VIDEO',
#  'COORDINATOR',
#  'CORNELIA GETRUDE PIENAAR',
#  'CORNELIUS ADOLF JANSE ODENDAL',
#  'CORNELIUS JOHANNES BOTHA',
#  'CORNELIUS JOHANNES LOTTERING',
#  'CORNELIUS JOHANNES VAN WYK',
#  'CORNELIUS PETRUS DE LANGE',
#  'CORNISH MMEKO MAKHANYA',
#  'COUNSEL',
#  'COUNSEL FOR KNOBEL',
#  'COURT',
#  'CRAIG KOTZE',
#  'CRAIG MACDONALD',
#  'CRAWFORD SIPHO NTSHANGASE',
#  'CRISIS COMMITTEE',
#  'CROSBY KOLANI NDINISA',
#  'CROSSBY MR BRINK',
#  'CRYING AND SCREAMING',
#  'CUNGANT QUEEN KENNY',
#  'CURRIN',
#  'CYRIL CHISOMA',
#  'CYRIL RAMAPHOSA',
#  'D MAY',
#  'D MOGWHATLE',
#  'D WORDSWORTH LETHULI',
#  'DAELE DANIEL THULO',
#  'DAISY MASHIGO',
#  'DALAQOLO WORDSWORTH LUTHULI',
#  'DALE WHITE',
#  'DALIMBI SIMEON LINDA',
#  'DALIWE MGULWA',
#  'DALUTXOLO WORDSWORTH LUTHULI',
#  'DALUXOLO WORDSWORTH LUTHULI',
#  'DAN MONTSISI',
#  'DANIEL BENJAMIN SNYDERS',
#  'DANIEL F DU TOIT BURGER',
#  'DANIEL FRANCOIS MALAN BOSMAN',
#  'DANIEL JAS',
#  'DANIEL JOHANNES MEYER',
#  'DANIEL LISUFI PHASHA',
#  'DANIEL MAGODA',
#  'DANIEL MAHAYIYA',
#  'DANIEL MAHESE BOOI',
#  'DANIEL MNINDWA MABENA',
#  'DANIEL MOLETE',
#  'DANIEL NCAYIYANA',
#  'DANIEL PAULOS NONGENA',
#  'DANIEL PETER KNOBEL',
#  'DANIEL PETRUS SIEBERT',
#  'DANIEL WANDILE LENNOX MENTILE',
#  'DANIEL WILHELM VAN DER WATT',
#  'DANILE WILBERFORCE MAY',
#  'DANNY RADEBE',
#  'DANNYBOY NYATHIKAZI',
#  'DANSON MOGOROSI',
#  'DAPHNEY RAMOKGOPA',
#  'DATE',
#  'DAVID DAYI GETVESE',
#  'DAVID ELVIS MAJOLA',
#  'DAVID ISAAKS',
#  'DAVID JOSEPH KLATZOW',
#  'DAVID MAAPE',
#  'DAVID MABEKA',
#  'DAVID MHLAPO',
#  'DAVID MUSOMO',
#  'DAVID NEMAKHAVANI',
#  'DAVID PHILIP ZWELI DLAMINI',
#  'DAVID PHILLIPS',
#  'DAVID S GASA',
#  'DAVID SMITH',
#  'DAVID TIJANE',
#  'DAVID TSHIKALANGA',
#  'DAVID VELELE MNGONA',
#  'DAVID WANLESS',
#  'DAVID ZHELI DLAMINI',
#  'DAVID ZIFOKOFE SILANGWE',
#  'DAVIS',
#  'DAVIS AND SEAPOINT',
#  'DAVIS V TIPP',
#  'DAWID JAKOBUS ACKERMAN',
#  'DAWID PETRUS BOTHA',
#  'DAWN GEORGINA BOTHA',
#  'DAY',
#  'DAZI DENIS SIMANGA',
#  'DE HARTEL',
#  'DE KOCK',
#  'DE WET JOHAN STRYDOM',
#  'DEBORAH NOMEISIE MZATI',
#  'DEBORAH VUYELWA JOKAZI',
#  'DEE DICKS',
#  'DENNIS CRUYWAGEN',
#  'DENZIL POTGIETER',
#  'DEON MARTIN',
#  'DEPOUTCH ELESE',
#  'DEREK GROOTBOOM',
#  'DEREK NAIDOO',
#  'DERICK FRANK SHONGWE',
#  'DERICK SKOSANA',
#  'DESMOND MPILO TUTU',
#  'DESMOND SMITH',
#  'DETAINED',
#  'DETAINED UNDER STATE OF',
#  'DETENTION',
#  'DHANPAL NAIDOO',
#  'DIALE JERRY MOKOBOJANE',
#  'DIDEKA GRACE MISHOMBO',
#  'DIKALEDI ADELAIDE MOTSANENG',
#  'DIKELEKI MORETI',
#  'DIKKIE MXOLISI JOHANNES JACOBS',
#  'DILALA MTSHAMBA',
#  'DILIZA MAYFORD MFAZWE',
#  'DILIZA MTHEMBU',
#  'DIMAKATSO NAKEDI',
#  'DINA ANVARI',
#  'DINAH MBUTHU',
#  'DINAH SIBONGILA MANYIKA',
#  'DINGI S NGWENYA',
#  'DINGILE MELITA SITHOLE',
#  'DIPHO MOKOENA',
#  'DIRK ADRIAAN VAN DER BANK',
#  'DIRK COETZEE',
#  'DIRK JOHANNES COETZEE',
#  'DISABILITY',
#  'DISAPPEARED IN EXILE',
#  'DISCO MOTHEGE',
#  'DISTRICT SURGEON',
#  'DITINI THYIDO',
#  'DJ MKHIZE',
#  'DLANJWA GCINISIZWE',
#  'DOKKIE ELIAS MAYISA',
#  'DOMINEE KWAHO',
#  'DOMINIC MSOMI AND MOSES PITSO',
#  'DOMINIKA MNGOMEZULU',
#  'DOMUSANI MBHEBE',
#  'DON BRISCOE',
#  'DON MATTERA',
#  'DONALD SERANI MUKHAWANA',
#  'DONALD SPENCER GOLD',
#  'DORA DZANANA MKHELE',
#  'DORA VUMAZONKE',
#  'DORCAS LUTHULI',
#  'DORIS MADELA',
#  'DORIS NOMALISA HLEKANI',
#  'DOROTHY HLATSHWAYO',
#  'DOROTHY SEATLHOLO',
#  'DOROTHY TSHABALALA',
#  'DOUGLAS BAX',
#  'DOUGLAS SIZWE NKWALI',
#  'DOUGLAS ZWENI',
#  'DOUW VERMEULEN',
#  'DR A MOOSA',
#  'DR AHMED MOOSA',
#  'DR ALI',
#  'DR BAQWA',
#  'DR BASSON',
#  'DR BORAINE',
#  'DR COLEMAN',
#  'DR COOPER',
#  'DR DANIEL',
#  'DR DU TOIT',
#  'DR DULNY',
#  'DR F AUERBACH',
#  'DR FAIZAL',
#  'DR FAZEL',
#  'DR FOURE',
#  'DR GIDEON KHABELA',
#  'DR GILDENHUYS',
#  'DR GOLDIN',
#  'DR GOLDMAN',
#  'DR GOOSEN',
#  'DR GRAHAM',
#  'DR HENRY THYSSE',
#  'DR K NAIK',
#  'DR KLATZOW',
#  'DR KLEPP',
#  'DR KNOBEL',
#  'DR LOURENS IS VIA HIS ATTORNEY',
#  'DR MAGOBELA',
#  'DR MAGWAZA',
#  'DR MALAN',
#  'DR MBOJO',
#  'DR MEER',
#  'DR MEINTJIES',
#  'DR MIJBURGH',
#  'DR MOKWEBO',
#  'DR NATHAN',
#  'DR NKOSI',
#  'DR OLIVER PRETORIUS',
#  'DR PRETORIUS',
#  'DR RADERA',
#  'DR RAMASHELA',
#  'DR RANDERA',
#  'DR RANDIRA',
#  'DR STALS',
#  'DR TOMS',
#  'DR TSOTI',
#  'DR TSOTSI',
#  'DR TSTOTSI',
#  'DR VAN HEERDEN',
#  'DR VAN RENSBERG',
#  'DR VAN RENSBURG',
#  'DR W M TSOTSI',
#  'DS DE KOCK',
#  'DUAL AMOS HLATSWAYO',
#  'DUGARD ZWELEDINGE MAQEKEZA',
#  'DUKAKILE AGNES MATHEBULA',
#  'DULLAH OMAR',
#  'DUMA KHUMALO',
#  'DUMA MOSES NKOSI',
#  'DUMISA MDLULWA',
#  'DUMISANI DUBE',
#  'DUMISANI ERNEST DLAMINI',
#  'DUMISANI MBHENSE',
#  'DUMISANI MTHEMBU',
#  'DUMISANI NCAMAZANA',
#  'DUMISANI NYOKA',
#  'DUMISANI PHUNGULA AND MRS PHUNGULA',
#  'DUMISANI TOKIZANI SIBISI',
#  'DUMSANE HAMILTON GUMEDE',
#  'DUMUSANI HENRY DLAMINI',
#  'DUNCAN VILLAGE HEARING',
#  'DURING MARCH',
#  'E ASVAT',
#  'E M THUNYISWA',
#  'E ZULU',
#  'EASTERN CAPE',
#  'EAZI MZIKHONANOFEMELA',
#  'EB OLIPHANT',
#  'EBRAHIM AKOOJEE',
#  'EBRAHIM ASVAT',
#  'EBRHIM RASOOL',
#  'EDDIE BALOYI',
#  'EDITH VANGILE MPANDE',
#  'EDMUND THEMBA WILLY',
#  'EDMUND ZONDI',
#  'EDWARD ALLAN PEARCE',
#  'EDWARD BARKER',
#  'EDWARD GUGWANA MENZI',
#  'EDWARD SHABANGU',
#  'EDWARD WEBB',
#  'EDWARD WILLIAM HOLDER',
#  'EDWIN B MOLAOLWA',
#  'EDWIN JOHN CLARK',
#  'EDWIN TOSIMELA SIMELANE',
#  'ELDA TSHABALALA',
#  'ELEANOR MAHLANGU',
#  'ELELWANI VIOLET MUGUVHELA',
#  'ELIAS DARA',
#  'ELIAS KESLA MTOLO',
#  'ELIAS MASHEGO',
#  'ELIAS MBATHA',
#  'ELIAS ZWANE',
#  'ELIAS ZWELAKHE SHANDU',
#  'ELINALE MASUPA',
#  'ELISA MAKAYA MNTUZE AND ABRAHAM MNTUZE',
#  'ELISA NTHANGENI',
#  'ELIZA MASILWANE',
#  'ELIZABETH ANNE SAVAGE',
#  'ELIZABETH BIBI',
#  'ELIZABETH DE LANGE',
#  'ELIZABETH FLORA ISAACS',
#  'ELIZABETH FLOYD',
#  'ELIZABETH JUDA',
#  'ELIZABETH LEDWABA',
#  'ELIZABETH MAAKE',
#  'ELIZABETH MASEKO',
#  'ELIZABETH MBATHA',
#  'ELIZABETH MEADE MOKONE',
#  'ELIZABETH NOTHEMBILE HASHE',
#  'ELIZABETH NOWAKHE BADI',
#  'ELIZABETH SEKATI',
#  'ELLA GLORIA MAHLOPHE',
#  'ELLEN DHLAMINI',
#  'ELLEN KALOTI',
#  'ELLEN KUZWAYO',
#  'ELLEN MOSHWEU',
#  'ELLEN VATHISWA BARNABUS',
#  'ELLIOT MBULELO JONGA',
#  'ELLIOT MICHAEL PAMA',
#  'ELLIOT NDLOVU',
#  'ELLIOTT SKHOSANA',
#  'ELPHAS MOLEFE',
#  'ELPHEUS MTHEMBU',
#  'ELSIE BUWA',
#  'ELSIE MANGANYE',
#  'ELSIE MOKOENA',
#  'EMBROSE NZIMKULU MAY',
#  'EMERGENCY',
#  'EMILY FOURIE',
#  'EMILY SIKADI MAGASHULE',
#  'EMILY SIKO',
#  'EMILY ZODWA CELE',
#  'EMMA NICHOLSON',
#  'EMMANUEL MOTOLLA',
#  'EMPLOYEES',
#  'EMPLOYER',
#  'END OF TAPE DUE TO POOR RECORDING',
#  'END OF TAPE SIDE A',
#  'ENDS',
#  'ENGLISH TRANSLATOR',
#  'ENIDE JAFTA',
#  'ENNIE MUNYAI',
#  'ENOCH MALI',
#  'ENOCK TSHABALALA',
#  'EPHRAIM MOGALE',
#  'EPHRAIM THAHETSI',
#  'ERIC BADI',
#  'ERIC MBANGO',
#  'ERIC NJOBO',
#  'ERIC WILLIAMS',
#  'ERICA DOREEN MOTSABE KOKUNSI',
#  'ERNEST LEKOTE PULE',
#  'ERNEST MTHETWA',
#  'ERNEST PHUMUZI SIGASA',
#  'ERNEST RAMATALA',
#  'ESTHER GRANT',
#  'ESTHER MTEMBU',
#  'ESTHER NYONGWANE',
#  'ETHEL NOMALUNGELO TIMBA',
#  'ETHEL RADEBE',
#  'ETIENNE J LE ROUX',
#  'EUGENE ALEXANDER DE KOCK',
#  'EUGENE DE KOCK',
#  'EUGENE MARAIS',
#  'EUGENE TERREBLANCHE',
#  'EUNICE DLOMO',
#  'EUNICE MANYE',
#  'EUNICE NOZIZWE NDABA',
#  'EUNICE SIMELANE',
#  'EUNICE SITHOLE',
#  'EVA LOKWALENG',
#  'EVELINA PULENG MOLOKO',
#  'EVELYN HOMBAKAZI SOLOMON',
#  'EVELYN M MORAKE',
#  'EVELYN MOSAGEDI',
#  'EVELYN MUHANE',
#  'EVENTS LEADING TO HIS DEATH',
#  'EXCERPTS OF VIDEO',
#  'EXECUTED',
#  'EXHIBIT A',
#  'EXHIBIT B',
#  'EXHIBIT G',
#  'EXHIBIT H',
#  'EXHIBIT R',
#  'EXHIBIT V',
#  'EZEKIEL MATSIDISO MARAIS',
#  'EZEKIEL MMOLAWA',
#  'F T T MASANGO',
#  'F TING TING MASANGO',
#  'FAAN VENTER',
#  'FABCOS SPEAKER',
#  'FAITH MBATHA',
#  'FAITH SEFATSANE',
#  'FANA HLONGWANE',
#  'FANA NDODA',
#  'FANELE LUNGU',
#  'FANIE ABRAHAM MKHWANAZI',
#  'FANIE SIMPIWE MBUTHO',
#  'FANISWA ILENE MALOSI',
#  'FANWELL MKHELE',
#  'FANYANA MAZIBUKO',
#  'FANYANA POTONG NHLAPHO',
#  'FATHER BUTI THLAGALE',
#  'FATHER GALVIN',
#  'FATHER LAPSLEY',
#  'FATHER MC CARTHY',
#  'FATHER MKHATSWA',
#  'FATHER NANGNA',
#  'FATHER SHANGE',
#  'FATHER WEEDER',
#  'FATIMA MOOSA',
#  'FELICIA AZANDE DLODLO',
#  'FELICIA NGWEVUSHA',
#  'FELICITY ANDERSON',
#  'FELIX THULANI KHESWA',
#  'FEMALE SPEAKER',
#  'FERDIE HARTZENBERG',
#  'FERDINAND BARNARD',
#  'FERREIRA',
#  'FEZILE DONALD MADODA JACOBS',
#  'FIKILE KOBESE',
#  'FIKILE MABASO',
#  'FIKILE NKOBESE',
#  'FLIP KOENRAAD THERON',
#  'FLOIT JOKA',
#  'FLOOR',
#  'FLORA MGOBHOZI',
#  'FLORENCE B LIBERTY',
#  'FLORENCE MBATHA',
#  'FLORENCE MKHIZE',
#  'FLORENCE MOLETE',
#  'FLORENCE NKOSI',
#  'FLORENCE NOMBUYISELO NOFEMELA',
#  'FOKWANE EUNICE MOKHOTHU',
#  'FOWZIA TURNER',
#  'FRANCINA BOPAPE',
#  'FRANCINA NTOPELA',
#  'FRANCISCO CERQUEIRA',
#  'FRANK ALBERT VAN NIEKERK',
#  'FRANK CHIKANE',
#  'FRANK GERMISHUIZEN',
#  'FRANK MCCARTER',
#  'FRANK XHOLA MBANE',
#  'FRANS MAUDA',
#  'FRANS MOBIKA MORWAENG',
#  'FRANS NTENDELENI MAVHUNGA',
#  'FRANS TUWANI MUDAU',
#  'FREDDIE JOSHUA MULAUDZI',
#  'FREDDIE TUTANI',
#  'FREDERICK EMMANUEL HUFKIE',
#  'FREDERICK HENDRIK DEMPSEY',
#  'FREDERICK JACOBUS BADENHORST',
#  'FREDERICK MFANAZOTINI MBUKAZI',
#  'FREDERIK CHRISTIAAN STEPHANUS SWARTS',
#  'FREDERIK JOHANNES PIENAAR',
#  'FREESTATE',
#  'FUMANIKILE BOOI',
#  'FUNANI SEPTEMBER BAMBELO',
#  'FUNDIKILE BLACKIE NOMBANGA',
#  'FUNDILE LAWRENCE GQUBULE',
#  'FUNDISELE GULENI',
#  'FUNDISILE GULENI',
#  'FUNEKA VOYIYA',
#  'FUSI SIMON MOFOKENG',
#  'G GQUBULE',
#  'G MEIRING OF SANDF AND TRC PANEL',
#  'G SIBACA',
#  'GABU TUGWANA',
#  'GALELEKILE NGAKI',
#  'GAREKWE THEKISO',
#  'GARINER MAJOVA',
#  'GARY DONOVAN ATKINSON',
#  'GARY GOVINDSAMY AND KASAVAN TERENCE ARENGASAMY',
#  'GARY JOHN KRUSER',
#  'GAUTENG',
#  'GCALASHE',
#  'GCINIKHAYA MAKOMA',
#  'GCINIKHAYACHRISTOPHER MAKOMA',
#  'GCINISIKO LAMONT DANDALA',
#  'GEBU FANYANA NGUBANE',
#  'GEJANE PAULINE MBIBA',
#  'GEN COMMANDS',
#  'GEN CONSTAND VILJOEN',
#  'GEN D T MASUKO',
#  'GEN DISCUSSION',
#  'GEN GROENEWALD',
#  'GEN JOUBERT',
#  'GEN M KNOBEL',
#  'GEN NEETHLING',
#  'GEN NYANDA',
#  'GEN STEYN',
#  'GEN VAN DER MERWE',
#  'GEN VAN DER WESTHUIZEN',
#  'GEN VILJOEN',
#  'GEORGE BERNARD MAHLANGU',
#  'GEORGE BIZOS',
#  'GEORGE DUBE',
#  'GEORGE LENTSELA',
#  'GEORGE LULAMILE KHWANKWA',
#  'GEORGE MPHOTSHA',
#  'GEORGE NDINI SIMAYILE',
#  'GEORGE NDLOZI',
#  ...]
